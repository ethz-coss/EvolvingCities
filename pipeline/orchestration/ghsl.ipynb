# %%
import ghsl_time_consistent_cluster as tcc
import config as config

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # 1. ETL Pipeline
# Here we extract the data from the pop and smod rasters and copy it to postigs.

# %%
tcc.load_ghsl_rasters()
# Out:
# Running bash script with arguments:
# CREATE EXTENSION
# CREATE EXTENSION
# Loading data for year 1975...
# BEGIN
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 171
# COPY 1000
# COPY 1000
# COPY 556
# COPY 648
# COPY 162
# COPY 45
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# COMMIT
# BEGIN
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 2
# COPY 1000
# COPY 1000
# COPY 556
# COPY 648
# COPY 162
# COPY 45
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# COMMIT
# Loading complete for 1975
# stderr: NOTICE:  extension "postgis" already exists, skipping
# NOTICE:  extension "postgis_raster" already exists, skipping
# Processing 1/1: /Users/andrea/Desktop/PhD/Data/API/clusterdb/data/ghsl/pop/GHS_POP_E1975_GLOBE_R2023A_54009_1000_V1_0.tif
# INFO: Using computed tile size: 256x256
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# Processing 1/1: /Users/andrea/Desktop/PhD/Data/API/clusterdb/data/ghsl/smod/GHS_SMOD_E1975_GLOBE_R2023A_54009_1000_V1_0.tif
# INFO: Using computed tile size: 256x256
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# Return code: 0
# Running bash script with arguments:
# CREATE EXTENSION
# CREATE EXTENSION
# Loading data for year 1980...
# BEGIN
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 171
# COPY 1000
# COPY 1000
# COPY 556
# COPY 648
# COPY 162
# COPY 45
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# COMMIT
# BEGIN
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 2
# COPY 1000
# COPY 1000
# COPY 556
# COPY 648
# COPY 162
# COPY 45
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# COMMIT
# Loading complete for 1980
# stderr: NOTICE:  extension "postgis" already exists, skipping
# NOTICE:  extension "postgis_raster" already exists, skipping
# Processing 1/1: /Users/andrea/Desktop/PhD/Data/API/clusterdb/data/ghsl/pop/GHS_POP_E1980_GLOBE_R2023A_54009_1000_V1_0.tif
# INFO: Using computed tile size: 256x256
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# Processing 1/1: /Users/andrea/Desktop/PhD/Data/API/clusterdb/data/ghsl/smod/GHS_SMOD_E1980_GLOBE_R2023A_54009_1000_V1_0.tif
# INFO: Using computed tile size: 256x256
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# Return code: 0
# Running bash script with arguments:
# CREATE EXTENSION
# CREATE EXTENSION
# Loading data for year 1985...
# BEGIN
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 171
# COPY 1000
# COPY 1000
# COPY 556
# COPY 648
# COPY 162
# COPY 45
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# COMMIT
# BEGIN
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 2
# COPY 1000
# COPY 1000
# COPY 556
# COPY 648
# COPY 162
# COPY 45
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# COMMIT
# Loading complete for 1985
# stderr: NOTICE:  extension "postgis" already exists, skipping
# NOTICE:  extension "postgis_raster" already exists, skipping
# Processing 1/1: /Users/andrea/Desktop/PhD/Data/API/clusterdb/data/ghsl/pop/GHS_POP_E1985_GLOBE_R2023A_54009_1000_V1_0.tif
# INFO: Using computed tile size: 256x256
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# Processing 1/1: /Users/andrea/Desktop/PhD/Data/API/clusterdb/data/ghsl/smod/GHS_SMOD_E1985_GLOBE_R2023A_54009_1000_V1_0.tif
# INFO: Using computed tile size: 256x256
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# Return code: 0
# Running bash script with arguments:
# CREATE EXTENSION
# CREATE EXTENSION
# Loading data for year 1990...
# BEGIN
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 171
# COPY 1000
# COPY 1000
# COPY 556
# COPY 648
# COPY 162
# COPY 45
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# COMMIT
# BEGIN
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 2
# COPY 1000
# COPY 1000
# COPY 556
# COPY 648
# COPY 162
# COPY 45
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# COMMIT
# Loading complete for 1990
# stderr: NOTICE:  extension "postgis" already exists, skipping
# NOTICE:  extension "postgis_raster" already exists, skipping
# Processing 1/1: /Users/andrea/Desktop/PhD/Data/API/clusterdb/data/ghsl/pop/GHS_POP_E1990_GLOBE_R2023A_54009_1000_V1_0.tif
# INFO: Using computed tile size: 256x256
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# Processing 1/1: /Users/andrea/Desktop/PhD/Data/API/clusterdb/data/ghsl/smod/GHS_SMOD_E1990_GLOBE_R2023A_54009_1000_V1_0.tif
# INFO: Using computed tile size: 256x256
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# Return code: 0
# Running bash script with arguments:
# CREATE EXTENSION
# CREATE EXTENSION
# Loading data for year 1995...
# BEGIN
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 171
# COPY 1000
# COPY 1000
# COPY 556
# COPY 648
# COPY 162
# COPY 45
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# COMMIT
# BEGIN
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 2
# COPY 1000
# COPY 1000
# COPY 556
# COPY 648
# COPY 162
# COPY 45
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# COMMIT
# Loading complete for 1995
# stderr: NOTICE:  extension "postgis" already exists, skipping
# NOTICE:  extension "postgis_raster" already exists, skipping
# Processing 1/1: /Users/andrea/Desktop/PhD/Data/API/clusterdb/data/ghsl/pop/GHS_POP_E1995_GLOBE_R2023A_54009_1000_V1_0.tif
# INFO: Using computed tile size: 256x256
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# Processing 1/1: /Users/andrea/Desktop/PhD/Data/API/clusterdb/data/ghsl/smod/GHS_SMOD_E1995_GLOBE_R2023A_54009_1000_V1_0.tif
# INFO: Using computed tile size: 256x256
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# Return code: 0
# Running bash script with arguments:
# CREATE EXTENSION
# CREATE EXTENSION
# Loading data for year 2000...
# BEGIN
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 171
# COPY 1000
# COPY 1000
# COPY 556
# COPY 648
# COPY 162
# COPY 45
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# COMMIT
# BEGIN
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 2
# COPY 1000
# COPY 1000
# COPY 556
# COPY 648
# COPY 162
# COPY 45
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# COMMIT
# Loading complete for 2000
# stderr: NOTICE:  extension "postgis" already exists, skipping
# NOTICE:  extension "postgis_raster" already exists, skipping
# Processing 1/1: /Users/andrea/Desktop/PhD/Data/API/clusterdb/data/ghsl/pop/GHS_POP_E2000_GLOBE_R2023A_54009_1000_V1_0.tif
# INFO: Using computed tile size: 256x256
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# Processing 1/1: /Users/andrea/Desktop/PhD/Data/API/clusterdb/data/ghsl/smod/GHS_SMOD_E2000_GLOBE_R2023A_54009_1000_V1_0.tif
# INFO: Using computed tile size: 256x256
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# Return code: 0
# Running bash script with arguments:
# CREATE EXTENSION
# CREATE EXTENSION
# Loading data for year 2005...
# BEGIN
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 171
# COPY 1000
# COPY 1000
# COPY 556
# COPY 648
# COPY 162
# COPY 45
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# COMMIT
# BEGIN
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 2
# COPY 1000
# COPY 1000
# COPY 556
# COPY 648
# COPY 162
# COPY 45
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# COMMIT
# Loading complete for 2005
# stderr: NOTICE:  extension "postgis" already exists, skipping
# NOTICE:  extension "postgis_raster" already exists, skipping
# Processing 1/1: /Users/andrea/Desktop/PhD/Data/API/clusterdb/data/ghsl/pop/GHS_POP_E2005_GLOBE_R2023A_54009_1000_V1_0.tif
# INFO: Using computed tile size: 256x256
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# Processing 1/1: /Users/andrea/Desktop/PhD/Data/API/clusterdb/data/ghsl/smod/GHS_SMOD_E2005_GLOBE_R2023A_54009_1000_V1_0.tif
# INFO: Using computed tile size: 256x256
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# Return code: 0
# Running bash script with arguments:
# CREATE EXTENSION
# CREATE EXTENSION
# Loading data for year 2010...
# BEGIN
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 171
# COPY 1000
# COPY 1000
# COPY 556
# COPY 648
# COPY 162
# COPY 45
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# COMMIT
# BEGIN
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 2
# COPY 1000
# COPY 1000
# COPY 556
# COPY 648
# COPY 162
# COPY 45
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# COMMIT
# Loading complete for 2010
# stderr: NOTICE:  extension "postgis" already exists, skipping
# NOTICE:  extension "postgis_raster" already exists, skipping
# Processing 1/1: /Users/andrea/Desktop/PhD/Data/API/clusterdb/data/ghsl/pop/GHS_POP_E2010_GLOBE_R2023A_54009_1000_V1_0.tif
# INFO: Using computed tile size: 256x256
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# Processing 1/1: /Users/andrea/Desktop/PhD/Data/API/clusterdb/data/ghsl/smod/GHS_SMOD_E2010_GLOBE_R2023A_54009_1000_V1_0.tif
# INFO: Using computed tile size: 256x256
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# Return code: 0
# Running bash script with arguments:
# CREATE EXTENSION
# CREATE EXTENSION
# Loading data for year 2015...
# BEGIN
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 171
# COPY 1000
# COPY 1000
# COPY 556
# COPY 648
# COPY 162
# COPY 45
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# COMMIT
# BEGIN
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 2
# COPY 1000
# COPY 1000
# COPY 556
# COPY 648
# COPY 162
# COPY 45
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# COMMIT
# Loading complete for 2015
# stderr: NOTICE:  extension "postgis" already exists, skipping
# NOTICE:  extension "postgis_raster" already exists, skipping
# Processing 1/1: /Users/andrea/Desktop/PhD/Data/API/clusterdb/data/ghsl/pop/GHS_POP_E2015_GLOBE_R2023A_54009_1000_V1_0.tif
# INFO: Using computed tile size: 256x256
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# Processing 1/1: /Users/andrea/Desktop/PhD/Data/API/clusterdb/data/ghsl/smod/GHS_SMOD_E2015_GLOBE_R2023A_54009_1000_V1_0.tif
# INFO: Using computed tile size: 256x256
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# Return code: 0
# Running bash script with arguments:
# CREATE EXTENSION
# CREATE EXTENSION
# Loading data for year 2020...
# BEGIN
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 171
# COPY 1000
# COPY 1000
# COPY 556
# COPY 648
# COPY 162
# COPY 45
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# COMMIT
# BEGIN
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# CREATE TABLE
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 1000
# COPY 2
# COPY 1000
# COPY 1000
# COPY 556
# COPY 648
# COPY 162
# COPY 45
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addrasterconstraints
# ----------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# addoverviewconstraints
# ------------------------
# t
# (1 row)
#
# COMMIT
# Loading complete for 2020
# stderr: NOTICE:  extension "postgis" already exists, skipping
# NOTICE:  extension "postgis_raster" already exists, skipping
# Processing 1/1: /Users/andrea/Desktop/PhD/Data/API/clusterdb/data/ghsl/pop/GHS_POP_E2020_GLOBE_R2023A_54009_1000_V1_0.tif
# INFO: Using computed tile size: 256x256
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# Processing 1/1: /Users/andrea/Desktop/PhD/Data/API/clusterdb/data/ghsl/smod/GHS_SMOD_E2020_GLOBE_R2023A_54009_1000_V1_0.tif
# INFO: Using computed tile size: 256x256
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# NOTICE:  Adding SRID constraint
# NOTICE:  Adding scale-X constraint
# NOTICE:  Adding scale-Y constraint
# NOTICE:  Adding blocksize-X constraint
# NOTICE:  Adding blocksize-Y constraint
# NOTICE:  Adding alignment constraint
# NOTICE:  Adding number of bands constraint
# NOTICE:  Adding pixel type constraint
# NOTICE:  Adding nodata value constraint
# NOTICE:  Adding out-of-database constraint
# NOTICE:  Adding maximum extent constraint
# Return code: 0

# %% [markdown]
# # 2. Clusters
# Here we build clusters, the central unit of analysis of this project. Clusters are defined build as follows:
# - 2.0 Extract urban areas from the smod raster and then compute population zonal statistics over those urban areas using the pop raster

# %%
tcc.create_cluster()
# Out:
# 2024-07-23 16:20:16,162 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2024-07-23 16:20:16,162 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-07-23 16:20:16,163 INFO sqlalchemy.engine.Engine select current_schema()
# 2024-07-23 16:20:16,163 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-07-23 16:20:16,164 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2024-07-23 16:20:16,164 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-07-23 16:20:16,165 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-07-23 16:20:16,168 INFO sqlalchemy.engine.Engine DROP TABLE IF EXISTS "cluster_1975";
#
# -- Create a binary raster from the smod raster with only urban and non-urban classes
# CREATE TEMPORARY TABLE smod_binary ON COMMIT DROP AS
# SELECT ST_Reclass(smod_1975.rast, 1,  '[0-21]:0, (21-30]:1', '1BB', nodataval := 0) AS rast
# FROM smod_1975;
#
# -- Create a temporary cluster geometry table with DBSCAN
# CREATE TEMPORARY TABLE cluster_geom ON COMMIT DROP AS
# WITH urban_pixels AS (
#     SELECT (ST_PixelAsPolygons(rast, 1, TRUE)).*
#     FROM smod_binary
# ),
# dbscan AS (
#     SELECT ST_ClusterDBSCAN(geom, eps := 1, minpoints := 1) OVER () AS cluster_id, geom
#     FROM urban_pixels
# )
# SELECT cluster_id, ST_Union(geom) AS geom
# FROM dbscan
# GROUP BY cluster_id;
#
# -- Create the cluster table with the geometry and population
# CREATE TABLE cluster_1975 AS
# WITH zonal_stats AS (
#     SELECT cluster_id, (St_SummaryStats(St_Union(ST_Clip(rast, 1, geom, true)))).*
#     FROM cluster_geom, pop_1975
#     WHERE St_Intersects(rast,geom)
#     GROUP BY cluster_id
# )
# SELECT cluster_id, sum AS population, geom
# FROM zonal_stats JOIN cluster_geom USING(cluster_id);
# 2024-07-23 16:20:16,168 INFO sqlalchemy.engine.Engine [generated in 0.00021s] {}
# 2024-07-23 16:26:21,590 INFO sqlalchemy.engine.Engine COMMIT
# 2024-07-23 16:26:21,597 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-07-23 16:26:21,599 INFO sqlalchemy.engine.Engine DROP TABLE IF EXISTS "cluster_1980";
#
# -- Create a binary raster from the smod raster with only urban and non-urban classes
# CREATE TEMPORARY TABLE smod_binary ON COMMIT DROP AS
# SELECT ST_Reclass(smod_1980.rast, 1,  '[0-21]:0, (21-30]:1', '1BB', nodataval := 0) AS rast
# FROM smod_1980;
#
# -- Create a temporary cluster geometry table with DBSCAN
# CREATE TEMPORARY TABLE cluster_geom ON COMMIT DROP AS
# WITH urban_pixels AS (
#     SELECT (ST_PixelAsPolygons(rast, 1, TRUE)).*
#     FROM smod_binary
# ),
# dbscan AS (
#     SELECT ST_ClusterDBSCAN(geom, eps := 1, minpoints := 1) OVER () AS cluster_id, geom
#     FROM urban_pixels
# )
# SELECT cluster_id, ST_Union(geom) AS geom
# FROM dbscan
# GROUP BY cluster_id;
#
# -- Create the cluster table with the geometry and population
# CREATE TABLE cluster_1980 AS
# WITH zonal_stats AS (
#     SELECT cluster_id, (St_SummaryStats(St_Union(ST_Clip(rast, 1, geom, true)))).*
#     FROM cluster_geom, pop_1980
#     WHERE St_Intersects(rast,geom)
#     GROUP BY cluster_id
# )
# SELECT cluster_id, sum AS population, geom
# FROM zonal_stats JOIN cluster_geom USING(cluster_id);
# 2024-07-23 16:26:21,599 INFO sqlalchemy.engine.Engine [generated in 0.00026s] {}
# 2024-07-23 16:32:56,199 INFO sqlalchemy.engine.Engine COMMIT
# 2024-07-23 16:32:56,205 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-07-23 16:32:56,206 INFO sqlalchemy.engine.Engine DROP TABLE IF EXISTS "cluster_1985";
#
# -- Create a binary raster from the smod raster with only urban and non-urban classes
# CREATE TEMPORARY TABLE smod_binary ON COMMIT DROP AS
# SELECT ST_Reclass(smod_1985.rast, 1,  '[0-21]:0, (21-30]:1', '1BB', nodataval := 0) AS rast
# FROM smod_1985;
#
# -- Create a temporary cluster geometry table with DBSCAN
# CREATE TEMPORARY TABLE cluster_geom ON COMMIT DROP AS
# WITH urban_pixels AS (
#     SELECT (ST_PixelAsPolygons(rast, 1, TRUE)).*
#     FROM smod_binary
# ),
# dbscan AS (
#     SELECT ST_ClusterDBSCAN(geom, eps := 1, minpoints := 1) OVER () AS cluster_id, geom
#     FROM urban_pixels
# )
# SELECT cluster_id, ST_Union(geom) AS geom
# FROM dbscan
# GROUP BY cluster_id;
#
# -- Create the cluster table with the geometry and population
# CREATE TABLE cluster_1985 AS
# WITH zonal_stats AS (
#     SELECT cluster_id, (St_SummaryStats(St_Union(ST_Clip(rast, 1, geom, true)))).*
#     FROM cluster_geom, pop_1985
#     WHERE St_Intersects(rast,geom)
#     GROUP BY cluster_id
# )
# SELECT cluster_id, sum AS population, geom
# FROM zonal_stats JOIN cluster_geom USING(cluster_id);
# 2024-07-23 16:32:56,207 INFO sqlalchemy.engine.Engine [generated in 0.00025s] {}
# 2024-07-23 16:39:46,506 INFO sqlalchemy.engine.Engine COMMIT
# 2024-07-23 16:39:46,512 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-07-23 16:39:46,514 INFO sqlalchemy.engine.Engine DROP TABLE IF EXISTS "cluster_1990";
#
# -- Create a binary raster from the smod raster with only urban and non-urban classes
# CREATE TEMPORARY TABLE smod_binary ON COMMIT DROP AS
# SELECT ST_Reclass(smod_1990.rast, 1,  '[0-21]:0, (21-30]:1', '1BB', nodataval := 0) AS rast
# FROM smod_1990;
#
# -- Create a temporary cluster geometry table with DBSCAN
# CREATE TEMPORARY TABLE cluster_geom ON COMMIT DROP AS
# WITH urban_pixels AS (
#     SELECT (ST_PixelAsPolygons(rast, 1, TRUE)).*
#     FROM smod_binary
# ),
# dbscan AS (
#     SELECT ST_ClusterDBSCAN(geom, eps := 1, minpoints := 1) OVER () AS cluster_id, geom
#     FROM urban_pixels
# )
# SELECT cluster_id, ST_Union(geom) AS geom
# FROM dbscan
# GROUP BY cluster_id;
#
# -- Create the cluster table with the geometry and population
# CREATE TABLE cluster_1990 AS
# WITH zonal_stats AS (
#     SELECT cluster_id, (St_SummaryStats(St_Union(ST_Clip(rast, 1, geom, true)))).*
#     FROM cluster_geom, pop_1990
#     WHERE St_Intersects(rast,geom)
#     GROUP BY cluster_id
# )
# SELECT cluster_id, sum AS population, geom
# FROM zonal_stats JOIN cluster_geom USING(cluster_id);
# 2024-07-23 16:39:46,514 INFO sqlalchemy.engine.Engine [generated in 0.00023s] {}
# 2024-07-23 16:47:06,488 INFO sqlalchemy.engine.Engine COMMIT
# 2024-07-23 16:47:06,496 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-07-23 16:47:06,498 INFO sqlalchemy.engine.Engine DROP TABLE IF EXISTS "cluster_1995";
#
# -- Create a binary raster from the smod raster with only urban and non-urban classes
# CREATE TEMPORARY TABLE smod_binary ON COMMIT DROP AS
# SELECT ST_Reclass(smod_1995.rast, 1,  '[0-21]:0, (21-30]:1', '1BB', nodataval := 0) AS rast
# FROM smod_1995;
#
# -- Create a temporary cluster geometry table with DBSCAN
# CREATE TEMPORARY TABLE cluster_geom ON COMMIT DROP AS
# WITH urban_pixels AS (
#     SELECT (ST_PixelAsPolygons(rast, 1, TRUE)).*
#     FROM smod_binary
# ),
# dbscan AS (
#     SELECT ST_ClusterDBSCAN(geom, eps := 1, minpoints := 1) OVER () AS cluster_id, geom
#     FROM urban_pixels
# )
# SELECT cluster_id, ST_Union(geom) AS geom
# FROM dbscan
# GROUP BY cluster_id;
#
# -- Create the cluster table with the geometry and population
# CREATE TABLE cluster_1995 AS
# WITH zonal_stats AS (
#     SELECT cluster_id, (St_SummaryStats(St_Union(ST_Clip(rast, 1, geom, true)))).*
#     FROM cluster_geom, pop_1995
#     WHERE St_Intersects(rast,geom)
#     GROUP BY cluster_id
# )
# SELECT cluster_id, sum AS population, geom
# FROM zonal_stats JOIN cluster_geom USING(cluster_id);
# 2024-07-23 16:47:06,498 INFO sqlalchemy.engine.Engine [generated in 0.00021s] {}
# 2024-07-23 16:54:50,745 INFO sqlalchemy.engine.Engine COMMIT
# 2024-07-23 16:54:50,752 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-07-23 16:54:50,754 INFO sqlalchemy.engine.Engine DROP TABLE IF EXISTS "cluster_2000";
#
# -- Create a binary raster from the smod raster with only urban and non-urban classes
# CREATE TEMPORARY TABLE smod_binary ON COMMIT DROP AS
# SELECT ST_Reclass(smod_2000.rast, 1,  '[0-21]:0, (21-30]:1', '1BB', nodataval := 0) AS rast
# FROM smod_2000;
#
# -- Create a temporary cluster geometry table with DBSCAN
# CREATE TEMPORARY TABLE cluster_geom ON COMMIT DROP AS
# WITH urban_pixels AS (
#     SELECT (ST_PixelAsPolygons(rast, 1, TRUE)).*
#     FROM smod_binary
# ),
# dbscan AS (
#     SELECT ST_ClusterDBSCAN(geom, eps := 1, minpoints := 1) OVER () AS cluster_id, geom
#     FROM urban_pixels
# )
# SELECT cluster_id, ST_Union(geom) AS geom
# FROM dbscan
# GROUP BY cluster_id;
#
# -- Create the cluster table with the geometry and population
# CREATE TABLE cluster_2000 AS
# WITH zonal_stats AS (
#     SELECT cluster_id, (St_SummaryStats(St_Union(ST_Clip(rast, 1, geom, true)))).*
#     FROM cluster_geom, pop_2000
#     WHERE St_Intersects(rast,geom)
#     GROUP BY cluster_id
# )
# SELECT cluster_id, sum AS population, geom
# FROM zonal_stats JOIN cluster_geom USING(cluster_id);
# 2024-07-23 16:54:50,754 INFO sqlalchemy.engine.Engine [generated in 0.00023s] {}
# 2024-07-23 17:02:49,978 INFO sqlalchemy.engine.Engine COMMIT
# 2024-07-23 17:02:49,986 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-07-23 17:02:49,987 INFO sqlalchemy.engine.Engine DROP TABLE IF EXISTS "cluster_2005";
#
# -- Create a binary raster from the smod raster with only urban and non-urban classes
# CREATE TEMPORARY TABLE smod_binary ON COMMIT DROP AS
# SELECT ST_Reclass(smod_2005.rast, 1,  '[0-21]:0, (21-30]:1', '1BB', nodataval := 0) AS rast
# FROM smod_2005;
#
# -- Create a temporary cluster geometry table with DBSCAN
# CREATE TEMPORARY TABLE cluster_geom ON COMMIT DROP AS
# WITH urban_pixels AS (
#     SELECT (ST_PixelAsPolygons(rast, 1, TRUE)).*
#     FROM smod_binary
# ),
# dbscan AS (
#     SELECT ST_ClusterDBSCAN(geom, eps := 1, minpoints := 1) OVER () AS cluster_id, geom
#     FROM urban_pixels
# )
# SELECT cluster_id, ST_Union(geom) AS geom
# FROM dbscan
# GROUP BY cluster_id;
#
# -- Create the cluster table with the geometry and population
# CREATE TABLE cluster_2005 AS
# WITH zonal_stats AS (
#     SELECT cluster_id, (St_SummaryStats(St_Union(ST_Clip(rast, 1, geom, true)))).*
#     FROM cluster_geom, pop_2005
#     WHERE St_Intersects(rast,geom)
#     GROUP BY cluster_id
# )
# SELECT cluster_id, sum AS population, geom
# FROM zonal_stats JOIN cluster_geom USING(cluster_id);
# 2024-07-23 17:02:49,988 INFO sqlalchemy.engine.Engine [generated in 0.00029s] {}
# 2024-07-23 17:11:03,800 INFO sqlalchemy.engine.Engine COMMIT
# 2024-07-23 17:11:03,805 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-07-23 17:11:03,807 INFO sqlalchemy.engine.Engine DROP TABLE IF EXISTS "cluster_2010";
#
# -- Create a binary raster from the smod raster with only urban and non-urban classes
# CREATE TEMPORARY TABLE smod_binary ON COMMIT DROP AS
# SELECT ST_Reclass(smod_2010.rast, 1,  '[0-21]:0, (21-30]:1', '1BB', nodataval := 0) AS rast
# FROM smod_2010;
#
# -- Create a temporary cluster geometry table with DBSCAN
# CREATE TEMPORARY TABLE cluster_geom ON COMMIT DROP AS
# WITH urban_pixels AS (
#     SELECT (ST_PixelAsPolygons(rast, 1, TRUE)).*
#     FROM smod_binary
# ),
# dbscan AS (
#     SELECT ST_ClusterDBSCAN(geom, eps := 1, minpoints := 1) OVER () AS cluster_id, geom
#     FROM urban_pixels
# )
# SELECT cluster_id, ST_Union(geom) AS geom
# FROM dbscan
# GROUP BY cluster_id;
#
# -- Create the cluster table with the geometry and population
# CREATE TABLE cluster_2010 AS
# WITH zonal_stats AS (
#     SELECT cluster_id, (St_SummaryStats(St_Union(ST_Clip(rast, 1, geom, true)))).*
#     FROM cluster_geom, pop_2010
#     WHERE St_Intersects(rast,geom)
#     GROUP BY cluster_id
# )
# SELECT cluster_id, sum AS population, geom
# FROM zonal_stats JOIN cluster_geom USING(cluster_id);
# 2024-07-23 17:11:03,807 INFO sqlalchemy.engine.Engine [generated in 0.00025s] {}
# 2024-07-23 17:19:36,733 INFO sqlalchemy.engine.Engine COMMIT
# 2024-07-23 17:19:36,739 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-07-23 17:19:36,741 INFO sqlalchemy.engine.Engine DROP TABLE IF EXISTS "cluster_2015";
#
# -- Create a binary raster from the smod raster with only urban and non-urban classes
# CREATE TEMPORARY TABLE smod_binary ON COMMIT DROP AS
# SELECT ST_Reclass(smod_2015.rast, 1,  '[0-21]:0, (21-30]:1', '1BB', nodataval := 0) AS rast
# FROM smod_2015;
#
# -- Create a temporary cluster geometry table with DBSCAN
# CREATE TEMPORARY TABLE cluster_geom ON COMMIT DROP AS
# WITH urban_pixels AS (
#     SELECT (ST_PixelAsPolygons(rast, 1, TRUE)).*
#     FROM smod_binary
# ),
# dbscan AS (
#     SELECT ST_ClusterDBSCAN(geom, eps := 1, minpoints := 1) OVER () AS cluster_id, geom
#     FROM urban_pixels
# )
# SELECT cluster_id, ST_Union(geom) AS geom
# FROM dbscan
# GROUP BY cluster_id;
#
# -- Create the cluster table with the geometry and population
# CREATE TABLE cluster_2015 AS
# WITH zonal_stats AS (
#     SELECT cluster_id, (St_SummaryStats(St_Union(ST_Clip(rast, 1, geom, true)))).*
#     FROM cluster_geom, pop_2015
#     WHERE St_Intersects(rast,geom)
#     GROUP BY cluster_id
# )
# SELECT cluster_id, sum AS population, geom
# FROM zonal_stats JOIN cluster_geom USING(cluster_id);
# 2024-07-23 17:19:36,741 INFO sqlalchemy.engine.Engine [generated in 0.00023s] {}
# 2024-07-23 17:28:17,517 INFO sqlalchemy.engine.Engine COMMIT
# 2024-07-23 17:28:17,522 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-07-23 17:28:17,524 INFO sqlalchemy.engine.Engine DROP TABLE IF EXISTS "cluster_2020";
#
# -- Create a binary raster from the smod raster with only urban and non-urban classes
# CREATE TEMPORARY TABLE smod_binary ON COMMIT DROP AS
# SELECT ST_Reclass(smod_2020.rast, 1,  '[0-21]:0, (21-30]:1', '1BB', nodataval := 0) AS rast
# FROM smod_2020;
#
# -- Create a temporary cluster geometry table with DBSCAN
# CREATE TEMPORARY TABLE cluster_geom ON COMMIT DROP AS
# WITH urban_pixels AS (
#     SELECT (ST_PixelAsPolygons(rast, 1, TRUE)).*
#     FROM smod_binary
# ),
# dbscan AS (
#     SELECT ST_ClusterDBSCAN(geom, eps := 1, minpoints := 1) OVER () AS cluster_id, geom
#     FROM urban_pixels
# )
# SELECT cluster_id, ST_Union(geom) AS geom
# FROM dbscan
# GROUP BY cluster_id;
#
# -- Create the cluster table with the geometry and population
# CREATE TABLE cluster_2020 AS
# WITH zonal_stats AS (
#     SELECT cluster_id, (St_SummaryStats(St_Union(ST_Clip(rast, 1, geom, true)))).*
#     FROM cluster_geom, pop_2020
#     WHERE St_Intersects(rast,geom)
#     GROUP BY cluster_id
# )
# SELECT cluster_id, sum AS population, geom
# FROM zonal_stats JOIN cluster_geom USING(cluster_id);
# 2024-07-23 17:28:17,524 INFO sqlalchemy.engine.Engine [generated in 0.00025s] {}
# 2024-07-23 17:37:04,093 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# # 3. Time consistent clusters
# Here we build time consistent clusters i.e., clusters having a consistent id across time. We do this by:
#
# - 3.1 Create a table with all clusters in all years. Create the "cluster intersection matching": a matching where two clusters (from different years) are matched if they intersect.
# - 3.2 Create a crosswalk table between cluster ids and time consistent cluster ids. Time consistent clusters are defined as connected components of bipartite graph representing the cluster intersection matching.
# - 3.3 Create a table with time consistent clusters geometry. Create a table with the time consistent cluster population across years.

# %%
tcc.create_multiyear_tables_and_cluster_intersection_matching()
# Out:
# 2024-07-23 17:37:04,228 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-07-23 17:37:04,229 INFO sqlalchemy.engine.Engine DROP TABLE IF EXISTS multiyear_cluster
# 2024-07-23 17:37:04,229 INFO sqlalchemy.engine.Engine [generated in 0.00025s] {}
# 2024-07-23 17:37:04,230 INFO sqlalchemy.engine.Engine CREATE TABLE multiyear_cluster AS (SELECT 1975 as year, cluster_id, population, geom FROM cluster_1975 UNION ALL SELECT 1980 as year, cluster_id, population, geom FROM cluster_1980 UNION ALL SELECT 1985 as year, cluster_id, population, geom FROM cluster_1985 UNION ALL SELECT 1990 as year, cluster_id, population, geom FROM cluster_1990 UNION ALL SELECT 1995 as year, cluster_id, population, geom FROM cluster_1995 UNION ALL SELECT 2000 as year, cluster_id, population, geom FROM cluster_2000 UNION ALL SELECT 2005 as year, cluster_id, population, geom FROM cluster_2005 UNION ALL SELECT 2010 as year, cluster_id, population, geom FROM cluster_2010 UNION ALL SELECT 2015 as year, cluster_id, population, geom FROM cluster_2015 UNION ALL SELECT 2020 as year, cluster_id, population, geom FROM cluster_2020 )
# 2024-07-23 17:37:04,230 INFO sqlalchemy.engine.Engine [generated in 0.00020s] {}
# 2024-07-23 17:37:04,886 INFO sqlalchemy.engine.Engine CREATE INDEX ON multiyear_cluster USING GIST (geom)
# 2024-07-23 17:37:04,887 INFO sqlalchemy.engine.Engine [generated in 0.00143s] {}
# 2024-07-23 17:37:05,602 INFO sqlalchemy.engine.Engine COMMIT
# 2024-07-23 17:37:05,607 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-07-23 17:37:05,607 INFO sqlalchemy.engine.Engine DROP TABLE IF EXISTS cluster_intersection_matching
# 2024-07-23 17:37:05,607 INFO sqlalchemy.engine.Engine [generated in 0.00024s] {}
# 2024-07-23 17:37:05,608 INFO sqlalchemy.engine.Engine
#         CREATE TABLE cluster_intersection_matching AS
#         SELECT c1.year as y1, c1.cluster_id AS id1, c2.year AS y2, c2.cluster_id AS id2
#         FROM multiyear_cluster c1 JOIN multiyear_cluster c2
#         ON ST_Intersects(c1.geom, c2.geom);
#
# 2024-07-23 17:37:05,608 INFO sqlalchemy.engine.Engine [generated in 0.00021s] {}
# 2024-07-23 17:37:41,908 INFO sqlalchemy.engine.Engine COMMIT

# %%
tcc.create_crosswalk_cluster_uid_to_cluster_id()
# Out:
# 2024-07-23 17:37:41,934 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-07-23 17:37:41,935 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2024-07-23 17:37:41,935 INFO sqlalchemy.engine.Engine [generated in 0.00075s] {'table_name': 'SELECT * FROM cluster_intersection_matching', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2024-07-23 17:37:41,937 INFO sqlalchemy.engine.Engine SELECT * FROM cluster_intersection_matching
# 2024-07-23 17:37:41,937 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-07-23 17:37:53,309 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-07-23 17:39:48,420 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-07-23 17:39:48,421 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2024-07-23 17:39:48,421 INFO sqlalchemy.engine.Engine [cached since 126.5s ago] {'table_name': 'crosswalk_cluster_uid_to_cluster_id', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2024-07-23 17:39:48,423 INFO sqlalchemy.engine.Engine
# CREATE TABLE crosswalk_cluster_uid_to_cluster_id (
# 	cluster_uid BIGINT,
# 	year BIGINT,
# 	cluster_id BIGINT
# )
#
#
# 2024-07-23 17:39:48,424 INFO sqlalchemy.engine.Engine [no key 0.00020s] {}
# 2024-07-23 17:39:50,284 INFO sqlalchemy.engine.Engine INSERT INTO crosswalk_cluster_uid_to_cluster_id (cluster_uid, year, cluster_id) VALUES (%(cluster_uid__0)s, %(year__0)s, %(cluster_id__0)s), (%(cluster_uid__1)s, %(year__1)s, %(cluster_id__1)s), (%(cluster_uid__2)s, %(year__2)s, %(cluster_id__2)s), ( ... 59405 characters truncated ... 8)s, %(year__998)s, %(cluster_id__998)s), (%(cluster_uid__999)s, %(year__999)s, %(cluster_id__999)s)
# 2024-07-23 17:39:50,285 INFO sqlalchemy.engine.Engine [generated in 1.61599s (insertmanyvalues) 1/967 (unordered)] {'cluster_uid__0': 0, 'year__0': 1985, 'cluster_id__0': 653, 'cluster_uid__1': 0, 'year__1': 2010, 'cluster_id__1': 669, 'cluster_uid__2': 0, 'year__2': 2005, 'cluster_id__2': 669, 'cluster_uid__3': 0, 'year__3': 1990, 'cluster_id__3': 662, 'cluster_uid__4': 0, 'year__4': 2015, 'cluster_id__4': 663, 'cluster_uid__5': 0, 'year__5': 2020, 'cluster_id__5': 655, 'cluster_uid__6': 0, 'year__6': 1995, 'cluster_id__6': 673, 'cluster_uid__7': 0, 'year__7': 1980, 'cluster_id__7': 649, 'cluster_uid__8': 0, 'year__8': 1975, 'cluster_id__8': 652, 'cluster_uid__9': 0, 'year__9': 2000, 'cluster_id__9': 673, 'cluster_uid__10': 1, 'year__10': 1975, 'cluster_id__10': 273, 'cluster_uid__11': 1, 'year__11': 1985, 'cluster_id__11': 269, 'cluster_uid__12': 1, 'year__12': 2015, 'cluster_id__12': 270, 'cluster_uid__13': 1, 'year__13': 2020, 'cluster_id__13': 266, 'cluster_uid__14': 1, 'year__14': 2010, 'cluster_id__14': 273, 'cluster_uid__15': 1, 'year__15': 1990, 'cluster_id__15': 270, 'cluster_uid__16': 1, 'year__16': 2000 ... 2900 parameters truncated ... 'year__983': 2015, 'cluster_id__983': 771, 'cluster_uid__984': 96, 'year__984': 2000, 'cluster_id__984': 778, 'cluster_uid__985': 97, 'year__985': 1995, 'cluster_id__985': 229, 'cluster_uid__986': 97, 'year__986': 2020, 'cluster_id__986': 217, 'cluster_uid__987': 97, 'year__987': 2000, 'cluster_id__987': 224, 'cluster_uid__988': 97, 'year__988': 2005, 'cluster_id__988': 222, 'cluster_uid__989': 97, 'year__989': 2015, 'cluster_id__989': 219, 'cluster_uid__990': 97, 'year__990': 1985, 'cluster_id__990': 221, 'cluster_uid__991': 97, 'year__991': 1990, 'cluster_id__991': 222, 'cluster_uid__992': 97, 'year__992': 2010, 'cluster_id__992': 221, 'cluster_uid__993': 97, 'year__993': 1980, 'cluster_id__993': 219, 'cluster_uid__994': 97, 'year__994': 1975, 'cluster_id__994': 222, 'cluster_uid__995': 98, 'year__995': 2015, 'cluster_id__995': 1035, 'cluster_uid__996': 98, 'year__996': 2000, 'cluster_id__996': 1052, 'cluster_uid__997': 98, 'year__997': 1990, 'cluster_id__997': 1036, 'cluster_uid__998': 98, 'year__998': 1995, 'cluster_id__998': 1055, 'cluster_uid__999': 98, 'year__999': 2005, 'cluster_id__999': 1047}
# 2024-07-23 17:39:50,305 INFO sqlalchemy.engine.Engine INSERT INTO crosswalk_cluster_uid_to_cluster_id (cluster_uid, year, cluster_id) VALUES (%(cluster_uid__0)s, %(year__0)s, %(cluster_id__0)s), (%(cluster_uid__1)s, %(year__1)s, %(cluster_id__1)s), (%(cluster_uid__2)s, %(year__2)s, %(cluster_id__2)s), ( ... 59405 characters truncated ... 8)s, %(year__998)s, %(cluster_id__998)s), (%(cluster_uid__999)s, %(year__999)s, %(cluster_id__999)s)
# 2024-07-23 17:39:50,305 INFO sqlalchemy.engine.Engine [insertmanyvalues 2/967 (unordered)] {'cluster_uid__0': 98, 'year__0': 1975, 'cluster_id__0': 1006, 'cluster_uid__1': 98, 'year__1': 2020, 'cluster_id__1': 1025, 'cluster_uid__2': 98, 'year__2': 1980, 'cluster_id__2': 1010, 'cluster_uid__3': 98, 'year__3': 2010, 'cluster_id__3': 1041, 'cluster_uid__4': 98, 'year__4': 1985, 'cluster_id__4': 1022, 'cluster_uid__5': 99, 'year__5': 1995, 'cluster_id__5': 1057, 'cluster_uid__6': 99, 'year__6': 2015, 'cluster_id__6': 1037, 'cluster_uid__7': 99, 'year__7': 2005, 'cluster_id__7': 1049, 'cluster_uid__8': 99, 'year__8': 1985, 'cluster_id__8': 1024, 'cluster_uid__9': 99, 'year__9': 1990, 'cluster_id__9': 1038, 'cluster_uid__10': 99, 'year__10': 2010, 'cluster_id__10': 1043, 'cluster_uid__11': 99, 'year__11': 2000, 'cluster_id__11': 1054, 'cluster_uid__12': 99, 'year__12': 1975, 'cluster_id__12': 1008, 'cluster_uid__13': 99, 'year__13': 2020, 'cluster_id__13': 1027, 'cluster_uid__14': 99, 'year__14': 1980, 'cluster_id__14': 1012, 'cluster_uid__15': 100, 'year__15': 1990, 'cluster_id__15': 794, 'cluster_uid__16': 100, 'year__16': 2005 ... 2900 parameters truncated ... 'year__983': 1995, 'cluster_id__983': 33, 'cluster_uid__984': 192, 'year__984': 2000, 'cluster_id__984': 33, 'cluster_uid__985': 193, 'year__985': 1980, 'cluster_id__985': 951, 'cluster_uid__986': 193, 'year__986': 1975, 'cluster_id__986': 947, 'cluster_uid__987': 193, 'year__987': 1985, 'cluster_id__987': 963, 'cluster_uid__988': 193, 'year__988': 2000, 'cluster_id__988': 997, 'cluster_uid__989': 193, 'year__989': 2015, 'cluster_id__989': 986, 'cluster_uid__990': 193, 'year__990': 2020, 'cluster_id__990': 982, 'cluster_uid__991': 193, 'year__991': 2005, 'cluster_id__991': 995, 'cluster_uid__992': 193, 'year__992': 2010, 'cluster_id__992': 992, 'cluster_uid__993': 193, 'year__993': 1990, 'cluster_id__993': 976, 'cluster_uid__994': 193, 'year__994': 1995, 'cluster_id__994': 996, 'cluster_uid__995': 194, 'year__995': 1995, 'cluster_id__995': 1028, 'cluster_uid__996': 194, 'year__996': 2000, 'cluster_id__996': 1026, 'cluster_uid__997': 194, 'year__997': 1990, 'cluster_id__997': 1006, 'cluster_uid__998': 194, 'year__998': 1985, 'cluster_id__998': 994, 'cluster_uid__999': 194, 'year__999': 1980, 'cluster_id__999': 982}
# 2024-07-23 17:39:50,314 INFO sqlalchemy.engine.Engine INSERT INTO crosswalk_cluster_uid_to_cluster_id (cluster_uid, year, cluster_id) VALUES (%(cluster_uid__0)s, %(year__0)s, %(cluster_id__0)s), (%(cluster_uid__1)s, %(year__1)s, %(cluster_id__1)s), (%(cluster_uid__2)s, %(year__2)s, %(cluster_id__2)s), ( ... 59405 characters truncated ... 8)s, %(year__998)s, %(cluster_id__998)s), (%(cluster_uid__999)s, %(year__999)s, %(cluster_id__999)s)
# 2024-07-23 17:39:50,315 INFO sqlalchemy.engine.Engine [insertmanyvalues 3/967 (unordered)] {'cluster_uid__0': 194, 'year__0': 1975, 'cluster_id__0': 978, 'cluster_uid__1': 195, 'year__1': 2015, 'cluster_id__1': 1009, 'cluster_uid__2': 195, 'year__2': 1975, 'cluster_id__2': 972, 'cluster_uid__3': 195, 'year__3': 1990, 'cluster_id__3': 1001, 'cluster_uid__4': 195, 'year__4': 1980, 'cluster_id__4': 976, 'cluster_uid__5': 195, 'year__5': 2000, 'cluster_id__5': 1021, 'cluster_uid__6': 195, 'year__6': 2020, 'cluster_id__6': 1000, 'cluster_uid__7': 195, 'year__7': 1985, 'cluster_id__7': 988, 'cluster_uid__8': 195, 'year__8': 1995, 'cluster_id__8': 1022, 'cluster_uid__9': 195, 'year__9': 2010, 'cluster_id__9': 1015, 'cluster_uid__10': 195, 'year__10': 2005, 'cluster_id__10': 1020, 'cluster_uid__11': 196, 'year__11': 1990, 'cluster_id__11': 778, 'cluster_uid__12': 196, 'year__12': 1975, 'cluster_id__12': 761, 'cluster_uid__13': 196, 'year__13': 1985, 'cluster_id__13': 767, 'cluster_uid__14': 196, 'year__14': 1995, 'cluster_id__14': 791, 'cluster_uid__15': 196, 'year__15': 2005, 'cluster_id__15': 790, 'cluster_uid__16': 196, 'year__16': 2000 ... 2900 parameters truncated ... 'year__983': 2010, 'cluster_id__983': 884, 'cluster_uid__984': 294, 'year__984': 2015, 'cluster_id__984': 878, 'cluster_uid__985': 294, 'year__985': 2005, 'cluster_id__985': 885, 'cluster_uid__986': 294, 'year__986': 1995, 'cluster_id__986': 883, 'cluster_uid__987': 294, 'year__987': 2020, 'cluster_id__987': 874, 'cluster_uid__988': 294, 'year__988': 2000, 'cluster_id__988': 886, 'cluster_uid__989': 294, 'year__989': 1990, 'cluster_id__989': 865, 'cluster_uid__990': 295, 'year__990': 2010, 'cluster_id__990': 739, 'cluster_uid__991': 295, 'year__991': 1980, 'cluster_id__991': 705, 'cluster_uid__992': 295, 'year__992': 1995, 'cluster_id__992': 738, 'cluster_uid__993': 295, 'year__993': 1985, 'cluster_id__993': 714, 'cluster_uid__994': 295, 'year__994': 1990, 'cluster_id__994': 725, 'cluster_uid__995': 295, 'year__995': 2020, 'cluster_id__995': 727, 'cluster_uid__996': 295, 'year__996': 2005, 'cluster_id__996': 738, 'cluster_uid__997': 295, 'year__997': 2015, 'cluster_id__997': 733, 'cluster_uid__998': 295, 'year__998': 1975, 'cluster_id__998': 710, 'cluster_uid__999': 295, 'year__999': 2000, 'cluster_id__999': 739}
# 2024-07-23 17:39:50,324 INFO sqlalchemy.engine.Engine INSERT INTO crosswalk_cluster_uid_to_cluster_id (cluster_uid, year, cluster_id) VALUES (%(cluster_uid__0)s, %(year__0)s, %(cluster_id__0)s), (%(cluster_uid__1)s, %(year__1)s, %(cluster_id__1)s), (%(cluster_uid__2)s, %(year__2)s, %(cluster_id__2)s), ( ... 59405 characters truncated ... 8)s, %(year__998)s, %(cluster_id__998)s), (%(cluster_uid__999)s, %(year__999)s, %(cluster_id__999)s)
# 2024-07-23 17:39:50,325 INFO sqlalchemy.engine.Engine [insertmanyvalues 4/967 (unordered)] {'cluster_uid__0': 296, 'year__0': 2010, 'cluster_id__0': 43, 'cluster_uid__1': 296, 'year__1': 1980, 'cluster_id__1': 47, 'cluster_uid__2': 296, 'year__2': 1975, 'cluster_id__2': 48, 'cluster_uid__3': 296, 'year__3': 2000, 'cluster_id__3': 47, 'cluster_uid__4': 296, 'year__4': 1995, 'cluster_id__4': 48, 'cluster_uid__5': 296, 'year__5': 2020, 'cluster_id__5': 44, 'cluster_uid__6': 296, 'year__6': 1990, 'cluster_id__6': 48, 'cluster_uid__7': 296, 'year__7': 2015, 'cluster_id__7': 43, 'cluster_uid__8': 296, 'year__8': 1985, 'cluster_id__8': 48, 'cluster_uid__9': 296, 'year__9': 2005, 'cluster_id__9': 45, 'cluster_uid__10': 297, 'year__10': 1975, 'cluster_id__10': 298, 'cluster_uid__11': 297, 'year__11': 1995, 'cluster_id__11': 307, 'cluster_uid__12': 297, 'year__12': 2010, 'cluster_id__12': 306, 'cluster_uid__13': 297, 'year__13': 2005, 'cluster_id__13': 306, 'cluster_uid__14': 297, 'year__14': 2015, 'cluster_id__14': 303, 'cluster_uid__15': 297, 'year__15': 1990, 'cluster_id__15': 298, 'cluster_uid__16': 297, 'year__16': 1985 ... 2900 parameters truncated ... 'year__983': 1985, 'cluster_id__983': 628, 'cluster_uid__984': 395, 'year__984': 1980, 'cluster_id__984': 624, 'cluster_uid__985': 395, 'year__985': 1990, 'cluster_id__985': 636, 'cluster_uid__986': 396, 'year__986': 2015, 'cluster_id__986': 104, 'cluster_uid__987': 396, 'year__987': 1980, 'cluster_id__987': 116, 'cluster_uid__988': 396, 'year__988': 2000, 'cluster_id__988': 113, 'cluster_uid__989': 396, 'year__989': 2005, 'cluster_id__989': 110, 'cluster_uid__990': 396, 'year__990': 2010, 'cluster_id__990': 104, 'cluster_uid__991': 396, 'year__991': 1975, 'cluster_id__991': 119, 'cluster_uid__992': 396, 'year__992': 1985, 'cluster_id__992': 116, 'cluster_uid__993': 396, 'year__993': 1995, 'cluster_id__993': 117, 'cluster_uid__994': 396, 'year__994': 2020, 'cluster_id__994': 104, 'cluster_uid__995': 396, 'year__995': 1990, 'cluster_id__995': 116, 'cluster_uid__996': 397, 'year__996': 1990, 'cluster_id__996': 308, 'cluster_uid__997': 397, 'year__997': 2010, 'cluster_id__997': 316, 'cluster_uid__998': 397, 'year__998': 1995, 'cluster_id__998': 317, 'cluster_uid__999': 397, 'year__999': 2005, 'cluster_id__999': 315}
# 2024-07-23 17:39:50,337 INFO sqlalchemy.engine.Engine INSERT INTO crosswalk_cluster_uid_to_cluster_id (cluster_uid, year, cluster_id) VALUES (%(cluster_uid__0)s, %(year__0)s, %(cluster_id__0)s), (%(cluster_uid__1)s, %(year__1)s, %(cluster_id__1)s), (%(cluster_uid__2)s, %(year__2)s, %(cluster_id__2)s), ( ... 59405 characters truncated ... 8)s, %(year__998)s, %(cluster_id__998)s), (%(cluster_uid__999)s, %(year__999)s, %(cluster_id__999)s)
# 2024-07-23 17:39:50,337 INFO sqlalchemy.engine.Engine [insertmanyvalues 5/967 (unordered)] {'cluster_uid__0': 397, 'year__0': 2000, 'cluster_id__0': 316, 'cluster_uid__1': 397, 'year__1': 1985, 'cluster_id__1': 306, 'cluster_uid__2': 397, 'year__2': 1975, 'cluster_id__2': 306, 'cluster_uid__3': 397, 'year__3': 2020, 'cluster_id__3': 310, 'cluster_uid__4': 397, 'year__4': 1980, 'cluster_id__4': 303, 'cluster_uid__5': 397, 'year__5': 2015, 'cluster_id__5': 315, 'cluster_uid__6': 398, 'year__6': 2000, 'cluster_id__6': 285, 'cluster_uid__7': 398, 'year__7': 1975, 'cluster_id__7': 286, 'cluster_uid__8': 398, 'year__8': 2005, 'cluster_id__8': 284, 'cluster_uid__9': 398, 'year__9': 1985, 'cluster_id__9': 283, 'cluster_uid__10': 398, 'year__10': 1995, 'cluster_id__10': 290, 'cluster_uid__11': 398, 'year__11': 2010, 'cluster_id__11': 284, 'cluster_uid__12': 398, 'year__12': 1980, 'cluster_id__12': 282, 'cluster_uid__13': 398, 'year__13': 2020, 'cluster_id__13': 277, 'cluster_uid__14': 398, 'year__14': 1990, 'cluster_id__14': 284, 'cluster_uid__15': 398, 'year__15': 2015, 'cluster_id__15': 281, 'cluster_uid__16': 399, 'year__16': 1980 ... 2900 parameters truncated ... 'year__983': 1980, 'cluster_id__983': 921, 'cluster_uid__984': 499, 'year__984': 1995, 'cluster_id__984': 966, 'cluster_uid__985': 499, 'year__985': 1990, 'cluster_id__985': 944, 'cluster_uid__986': 499, 'year__986': 2010, 'cluster_id__986': 964, 'cluster_uid__987': 500, 'year__987': 1975, 'cluster_id__987': 156, 'cluster_uid__988': 500, 'year__988': 1980, 'cluster_id__988': 153, 'cluster_uid__989': 500, 'year__989': 1985, 'cluster_id__989': 155, 'cluster_uid__990': 500, 'year__990': 1995, 'cluster_id__990': 162, 'cluster_uid__991': 500, 'year__991': 2000, 'cluster_id__991': 157, 'cluster_uid__992': 500, 'year__992': 2020, 'cluster_id__992': 154, 'cluster_uid__993': 500, 'year__993': 2015, 'cluster_id__993': 154, 'cluster_uid__994': 500, 'year__994': 2010, 'cluster_id__994': 154, 'cluster_uid__995': 500, 'year__995': 2005, 'cluster_id__995': 155, 'cluster_uid__996': 500, 'year__996': 1990, 'cluster_id__996': 157, 'cluster_uid__997': 501, 'year__997': 1985, 'cluster_id__997': 947, 'cluster_uid__998': 501, 'year__998': 1980, 'cluster_id__998': 936, 'cluster_uid__999': 501, 'year__999': 1975, 'cluster_id__999': 932}
# 2024-07-23 17:39:50,347 INFO sqlalchemy.engine.Engine INSERT INTO crosswalk_cluster_uid_to_cluster_id (cluster_uid, year, cluster_id) VALUES (%(cluster_uid__0)s, %(year__0)s, %(cluster_id__0)s), (%(cluster_uid__1)s, %(year__1)s, %(cluster_id__1)s), (%(cluster_uid__2)s, %(year__2)s, %(cluster_id__2)s), ( ... 59405 characters truncated ... 8)s, %(year__998)s, %(cluster_id__998)s), (%(cluster_uid__999)s, %(year__999)s, %(cluster_id__999)s)
# 2024-07-23 17:39:50,347 INFO sqlalchemy.engine.Engine [insertmanyvalues 6/967 (unordered)] {'cluster_uid__0': 501, 'year__0': 2005, 'cluster_id__0': 979, 'cluster_uid__1': 501, 'year__1': 2000, 'cluster_id__1': 981, 'cluster_uid__2': 501, 'year__2': 1990, 'cluster_id__2': 960, 'cluster_uid__3': 501, 'year__3': 2010, 'cluster_id__3': 976, 'cluster_uid__4': 501, 'year__4': 2015, 'cluster_id__4': 970, 'cluster_uid__5': 501, 'year__5': 2020, 'cluster_id__5': 968, 'cluster_uid__6': 501, 'year__6': 1995, 'cluster_id__6': 980, 'cluster_uid__7': 502, 'year__7': 2020, 'cluster_id__7': 642, 'cluster_uid__8': 502, 'year__8': 2010, 'cluster_id__8': 656, 'cluster_uid__9': 502, 'year__9': 1985, 'cluster_id__9': 642, 'cluster_uid__10': 502, 'year__10': 1975, 'cluster_id__10': 641, 'cluster_uid__11': 502, 'year__11': 1990, 'cluster_id__11': 650, 'cluster_uid__12': 502, 'year__12': 2005, 'cluster_id__12': 657, 'cluster_uid__13': 502, 'year__13': 2015, 'cluster_id__13': 650, 'cluster_uid__14': 502, 'year__14': 1995, 'cluster_id__14': 661, 'cluster_uid__15': 502, 'year__15': 1980, 'cluster_id__15': 638, 'cluster_uid__16': 502, 'year__16': 2000 ... 2900 parameters truncated ... 'year__983': 2010, 'cluster_id__983': 790, 'cluster_uid__984': 603, 'year__984': 2015, 'cluster_id__984': 784, 'cluster_uid__985': 603, 'year__985': 1995, 'cluster_id__985': 792, 'cluster_uid__986': 603, 'year__986': 2000, 'cluster_id__986': 793, 'cluster_uid__987': 603, 'year__987': 1975, 'cluster_id__987': 762, 'cluster_uid__988': 603, 'year__988': 1980, 'cluster_id__988': 758, 'cluster_uid__989': 604, 'year__989': 2010, 'cluster_id__989': 741, 'cluster_uid__990': 604, 'year__990': 1980, 'cluster_id__990': 707, 'cluster_uid__991': 604, 'year__991': 1985, 'cluster_id__991': 716, 'cluster_uid__992': 604, 'year__992': 1975, 'cluster_id__992': 712, 'cluster_uid__993': 604, 'year__993': 1990, 'cluster_id__993': 727, 'cluster_uid__994': 604, 'year__994': 2000, 'cluster_id__994': 741, 'cluster_uid__995': 604, 'year__995': 1995, 'cluster_id__995': 740, 'cluster_uid__996': 604, 'year__996': 2020, 'cluster_id__996': 729, 'cluster_uid__997': 604, 'year__997': 2015, 'cluster_id__997': 735, 'cluster_uid__998': 604, 'year__998': 2005, 'cluster_id__998': 740, 'cluster_uid__999': 605, 'year__999': 1990, 'cluster_id__999': 192}
# 2024-07-23 17:39:50,356 INFO sqlalchemy.engine.Engine INSERT INTO crosswalk_cluster_uid_to_cluster_id (cluster_uid, year, cluster_id) VALUES (%(cluster_uid__0)s, %(year__0)s, %(cluster_id__0)s), (%(cluster_uid__1)s, %(year__1)s, %(cluster_id__1)s), (%(cluster_uid__2)s, %(year__2)s, %(cluster_id__2)s), ( ... 59405 characters truncated ... 8)s, %(year__998)s, %(cluster_id__998)s), (%(cluster_uid__999)s, %(year__999)s, %(cluster_id__999)s)
# 2024-07-23 17:39:50,357 INFO sqlalchemy.engine.Engine [insertmanyvalues 7/967 (unordered)] {'cluster_uid__0': 605, 'year__0': 1980, 'cluster_id__0': 189, 'cluster_uid__1': 605, 'year__1': 1975, 'cluster_id__1': 192, 'cluster_uid__2': 605, 'year__2': 1995, 'cluster_id__2': 199, 'cluster_uid__3': 605, 'year__3': 2000, 'cluster_id__3': 193, 'cluster_uid__4': 605, 'year__4': 2015, 'cluster_id__4': 190, 'cluster_uid__5': 605, 'year__5': 2020, 'cluster_id__5': 190, 'cluster_uid__6': 605, 'year__6': 1985, 'cluster_id__6': 191, 'cluster_uid__7': 605, 'year__7': 2010, 'cluster_id__7': 192, 'cluster_uid__8': 605, 'year__8': 2005, 'cluster_id__8': 193, 'cluster_uid__9': 606, 'year__9': 2010, 'cluster_id__9': 538, 'cluster_uid__10': 606, 'year__10': 1995, 'cluster_id__10': 531, 'cluster_uid__11': 606, 'year__11': 1980, 'cluster_id__11': 513, 'cluster_uid__12': 606, 'year__12': 1975, 'cluster_id__12': 513, 'cluster_uid__13': 606, 'year__13': 2000, 'cluster_id__13': 534, 'cluster_uid__14': 606, 'year__14': 1985, 'cluster_id__14': 518, 'cluster_uid__15': 606, 'year__15': 2020, 'cluster_id__15': 529, 'cluster_uid__16': 606, 'year__16': 2005 ... 2900 parameters truncated ... 'year__983': 2010, 'cluster_id__983': 760, 'cluster_uid__984': 707, 'year__984': 1990, 'cluster_id__984': 747, 'cluster_uid__985': 707, 'year__985': 1995, 'cluster_id__985': 760, 'cluster_uid__986': 708, 'year__986': 1990, 'cluster_id__986': 409, 'cluster_uid__987': 708, 'year__987': 2010, 'cluster_id__987': 428, 'cluster_uid__988': 708, 'year__988': 2020, 'cluster_id__988': 420, 'cluster_uid__989': 708, 'year__989': 1980, 'cluster_id__989': 400, 'cluster_uid__990': 708, 'year__990': 2000, 'cluster_id__990': 425, 'cluster_uid__991': 708, 'year__991': 1985, 'cluster_id__991': 406, 'cluster_uid__992': 708, 'year__992': 2005, 'cluster_id__992': 427, 'cluster_uid__993': 708, 'year__993': 1975, 'cluster_id__993': 403, 'cluster_uid__994': 708, 'year__994': 1995, 'cluster_id__994': 423, 'cluster_uid__995': 708, 'year__995': 2015, 'cluster_id__995': 427, 'cluster_uid__996': 709, 'year__996': 2005, 'cluster_id__996': 252, 'cluster_uid__997': 709, 'year__997': 2000, 'cluster_id__997': 254, 'cluster_uid__998': 709, 'year__998': 2020, 'cluster_id__998': 245, 'cluster_uid__999': 709, 'year__999': 1990, 'cluster_id__999': 252}
# 2024-07-23 17:39:50,368 INFO sqlalchemy.engine.Engine INSERT INTO crosswalk_cluster_uid_to_cluster_id (cluster_uid, year, cluster_id) VALUES (%(cluster_uid__0)s, %(year__0)s, %(cluster_id__0)s), (%(cluster_uid__1)s, %(year__1)s, %(cluster_id__1)s), (%(cluster_uid__2)s, %(year__2)s, %(cluster_id__2)s), ( ... 59405 characters truncated ... 8)s, %(year__998)s, %(cluster_id__998)s), (%(cluster_uid__999)s, %(year__999)s, %(cluster_id__999)s)
# 2024-07-23 17:39:50,369 INFO sqlalchemy.engine.Engine [insertmanyvalues 8/967 (unordered)] {'cluster_uid__0': 709, 'year__0': 1985, 'cluster_id__0': 252, 'cluster_uid__1': 709, 'year__1': 2010, 'cluster_id__1': 251, 'cluster_uid__2': 709, 'year__2': 1980, 'cluster_id__2': 252, 'cluster_uid__3': 709, 'year__3': 1975, 'cluster_id__3': 256, 'cluster_uid__4': 709, 'year__4': 1995, 'cluster_id__4': 259, 'cluster_uid__5': 709, 'year__5': 2015, 'cluster_id__5': 249, 'cluster_uid__6': 710, 'year__6': 2015, 'cluster_id__6': 665, 'cluster_uid__7': 710, 'year__7': 1990, 'cluster_id__7': 664, 'cluster_uid__8': 710, 'year__8': 2000, 'cluster_id__8': 675, 'cluster_uid__9': 710, 'year__9': 2005, 'cluster_id__9': 671, 'cluster_uid__10': 710, 'year__10': 1980, 'cluster_id__10': 651, 'cluster_uid__11': 710, 'year__11': 1995, 'cluster_id__11': 675, 'cluster_uid__12': 710, 'year__12': 1985, 'cluster_id__12': 655, 'cluster_uid__13': 710, 'year__13': 1975, 'cluster_id__13': 654, 'cluster_uid__14': 710, 'year__14': 2010, 'cluster_id__14': 671, 'cluster_uid__15': 710, 'year__15': 2020, 'cluster_id__15': 657, 'cluster_uid__16': 711, 'year__16': 2020 ... 2900 parameters truncated ... 'year__983': 1975, 'cluster_id__983': 5684, 'cluster_uid__984': 808, 'year__984': 2000, 'cluster_id__984': 3427, 'cluster_uid__985': 808, 'year__985': 2010, 'cluster_id__985': 3383, 'cluster_uid__986': 808, 'year__986': 1980, 'cluster_id__986': 3267, 'cluster_uid__987': 808, 'year__987': 1990, 'cluster_id__987': 3338, 'cluster_uid__988': 808, 'year__988': 1975, 'cluster_id__988': 3251, 'cluster_uid__989': 808, 'year__989': 1985, 'cluster_id__989': 3304, 'cluster_uid__990': 808, 'year__990': 1995, 'cluster_id__990': 3424, 'cluster_uid__991': 808, 'year__991': 2015, 'cluster_id__991': 3400, 'cluster_uid__992': 808, 'year__992': 2005, 'cluster_id__992': 3394, 'cluster_uid__993': 808, 'year__993': 2020, 'cluster_id__993': 3370, 'cluster_uid__994': 809, 'year__994': 1975, 'cluster_id__994': 2567, 'cluster_uid__995': 809, 'year__995': 1990, 'cluster_id__995': 2628, 'cluster_uid__996': 809, 'year__996': 2005, 'cluster_id__996': 2651, 'cluster_uid__997': 809, 'year__997': 2000, 'cluster_id__997': 2685, 'cluster_uid__998': 809, 'year__998': 1985, 'cluster_id__998': 2606, 'cluster_uid__999': 809, 'year__999': 2010, 'cluster_id__999': 2639}
# 2024-07-23 17:39:50,385 INFO sqlalchemy.engine.Engine INSERT INTO crosswalk_cluster_uid_to_cluster_id (cluster_uid, year, cluster_id) VALUES (%(cluster_uid__0)s, %(year__0)s, %(cluster_id__0)s), (%(cluster_uid__1)s, %(year__1)s, %(cluster_id__1)s), (%(cluster_uid__2)s, %(year__2)s, %(cluster_id__2)s), ( ... 59405 characters truncated ... 8)s, %(year__998)s, %(cluster_id__998)s), (%(cluster_uid__999)s, %(year__999)s, %(cluster_id__999)s)
# 2024-07-23 17:39:50,386 INFO sqlalchemy.engine.Engine [insertmanyvalues 9/967 (unordered)] {'cluster_uid__0': 809, 'year__0': 2015, 'cluster_id__0': 2644, 'cluster_uid__1': 809, 'year__1': 1995, 'cluster_id__1': 2690, 'cluster_uid__2': 809, 'year__2': 2020, 'cluster_id__2': 2627, 'cluster_uid__3': 809, 'year__3': 1980, 'cluster_id__3': 2583, 'cluster_uid__4': 810, 'year__4': 2000, 'cluster_id__4': 15065, 'cluster_uid__5': 810, 'year__5': 1985, 'cluster_id__5': 14639, 'cluster_uid__6': 810, 'year__6': 1990, 'cluster_id__6': 14905, 'cluster_uid__7': 810, 'year__7': 1995, 'cluster_id__7': 15106, 'cluster_uid__8': 810, 'year__8': 2020, 'cluster_id__8': 15024, 'cluster_uid__9': 810, 'year__9': 2005, 'cluster_id__9': 15041, 'cluster_uid__10': 810, 'year__10': 2010, 'cluster_id__10': 15089, 'cluster_uid__11': 810, 'year__11': 2015, 'cluster_id__11': 15177, 'cluster_uid__12': 810, 'year__12': 1975, 'cluster_id__12': 14247, 'cluster_uid__13': 810, 'year__13': 1980, 'cluster_id__13': 14435, 'cluster_uid__14': 811, 'year__14': 2000, 'cluster_id__14': 11115, 'cluster_uid__15': 811, 'year__15': 1985, 'cluster_id__15': 10812, 'cluster_uid__16': 811, 'year__16': 1980 ... 2900 parameters truncated ... 'year__983': 2005, 'cluster_id__983': 19167, 'cluster_uid__984': 895, 'year__984': 1990, 'cluster_id__984': 18995, 'cluster_uid__985': 895, 'year__985': 2000, 'cluster_id__985': 19176, 'cluster_uid__986': 895, 'year__986': 1985, 'cluster_id__986': 18623, 'cluster_uid__987': 895, 'year__987': 2000, 'cluster_id__987': 19172, 'cluster_uid__988': 895, 'year__988': 1995, 'cluster_id__988': 19219, 'cluster_uid__989': 895, 'year__989': 1980, 'cluster_id__989': 18315, 'cluster_uid__990': 895, 'year__990': 1980, 'cluster_id__990': 18317, 'cluster_uid__991': 895, 'year__991': 1995, 'cluster_id__991': 19215, 'cluster_uid__992': 895, 'year__992': 1975, 'cluster_id__992': 18036, 'cluster_uid__993': 895, 'year__993': 2020, 'cluster_id__993': 19184, 'cluster_uid__994': 895, 'year__994': 1975, 'cluster_id__994': 18033, 'cluster_uid__995': 896, 'year__995': 1995, 'cluster_id__995': 5353, 'cluster_uid__996': 896, 'year__996': 2020, 'cluster_id__996': 5229, 'cluster_uid__997': 896, 'year__997': 2005, 'cluster_id__997': 5315, 'cluster_uid__998': 896, 'year__998': 2000, 'cluster_id__998': 5353, 'cluster_uid__999': 896, 'year__999': 1975, 'cluster_id__999': 5162}
# 2024-07-23 17:39:50,398 INFO sqlalchemy.engine.Engine INSERT INTO crosswalk_cluster_uid_to_cluster_id (cluster_uid, year, cluster_id) VALUES (%(cluster_uid__0)s, %(year__0)s, %(cluster_id__0)s), (%(cluster_uid__1)s, %(year__1)s, %(cluster_id__1)s), (%(cluster_uid__2)s, %(year__2)s, %(cluster_id__2)s), ( ... 59405 characters truncated ... 8)s, %(year__998)s, %(cluster_id__998)s), (%(cluster_uid__999)s, %(year__999)s, %(cluster_id__999)s)
# 2024-07-23 17:39:50,399 INFO sqlalchemy.engine.Engine [insertmanyvalues 10/967 (unordered)] {'cluster_uid__0': 896, 'year__0': 1980, 'cluster_id__0': 5175, 'cluster_uid__1': 896, 'year__1': 1985, 'cluster_id__1': 5219, 'cluster_uid__2': 896, 'year__2': 2010, 'cluster_id__2': 5287, 'cluster_uid__3': 896, 'year__3': 2015, 'cluster_id__3': 5285, 'cluster_uid__4': 896, 'year__4': 1990, 'cluster_id__4': 5261, 'cluster_uid__5': 897, 'year__5': 1985, 'cluster_id__5': 13784, 'cluster_uid__6': 897, 'year__6': 2010, 'cluster_id__6': 14175, 'cluster_uid__7': 897, 'year__7': 2005, 'cluster_id__7': 14128, 'cluster_uid__8': 897, 'year__8': 1980, 'cluster_id__8': 13634, 'cluster_uid__9': 897, 'year__9': 2020, 'cluster_id__9': 14074, 'cluster_uid__10': 897, 'year__10': 1990, 'cluster_id__10': 13985, 'cluster_uid__11': 897, 'year__11': 1995, 'cluster_id__11': 14188, 'cluster_uid__12': 897, 'year__12': 2015, 'cluster_id__12': 14240, 'cluster_uid__13': 897, 'year__13': 2000, 'cluster_id__13': 14165, 'cluster_uid__14': 897, 'year__14': 1975, 'cluster_id__14': 13478, 'cluster_uid__15': 898, 'year__15': 1975, 'cluster_id__15': 7354, 'cluster_uid__16': 898, 'year__16': 2005 ... 2900 parameters truncated ... 'year__983': 1995, 'cluster_id__983': 797, 'cluster_uid__984': 992, 'year__984': 1985, 'cluster_id__984': 773, 'cluster_uid__985': 992, 'year__985': 2015, 'cluster_id__985': 789, 'cluster_uid__986': 992, 'year__986': 2000, 'cluster_id__986': 798, 'cluster_uid__987': 992, 'year__987': 1975, 'cluster_id__987': 767, 'cluster_uid__988': 992, 'year__988': 2020, 'cluster_id__988': 782, 'cluster_uid__989': 993, 'year__989': 1980, 'cluster_id__989': 2161, 'cluster_uid__990': 993, 'year__990': 2020, 'cluster_id__990': 2233, 'cluster_uid__991': 993, 'year__991': 1975, 'cluster_id__991': 2145, 'cluster_uid__992': 993, 'year__992': 1995, 'cluster_id__992': 2245, 'cluster_uid__993': 993, 'year__993': 1990, 'cluster_id__993': 2194, 'cluster_uid__994': 993, 'year__994': 1985, 'cluster_id__994': 2172, 'cluster_uid__995': 993, 'year__995': 2000, 'cluster_id__995': 2240, 'cluster_uid__996': 993, 'year__996': 2010, 'cluster_id__996': 2224, 'cluster_uid__997': 993, 'year__997': 2005, 'cluster_id__997': 2223, 'cluster_uid__998': 993, 'year__998': 2015, 'cluster_id__998': 2239, 'cluster_uid__999': 994, 'year__999': 1975, 'cluster_id__999': 6719}
# 2024-07-23 17:39:50,411 INFO sqlalchemy.engine.Engine INSERT INTO crosswalk_cluster_uid_to_cluster_id (cluster_uid, year, cluster_id) VALUES (%(cluster_uid__0)s, %(year__0)s, %(cluster_id__0)s), (%(cluster_uid__1)s, %(year__1)s, %(cluster_id__1)s), (%(cluster_uid__2)s, %(year__2)s, %(cluster_id__2)s), ( ... 59405 characters truncated ... 8)s, %(year__998)s, %(cluster_id__998)s), (%(cluster_uid__999)s, %(year__999)s, %(cluster_id__999)s)
# 2024-07-23 17:39:50,411 INFO sqlalchemy.engine.Engine [insertmanyvalues 11/967 (unordered)] {'cluster_uid__0': 994, 'year__0': 1985, 'cluster_id__0': 6795, 'cluster_uid__1': 994, 'year__1': 2005, 'cluster_id__1': 6958, 'cluster_uid__2': 994, 'year__2': 2010, 'cluster_id__2': 6930, 'cluster_uid__3': 994, 'year__3': 1990, 'cluster_id__3': 6872, 'cluster_uid__4': 994, 'year__4': 1980, 'cluster_id__4': 6727, 'cluster_uid__5': 994, 'year__5': 2000, 'cluster_id__5': 7007, 'cluster_uid__6': 994, 'year__6': 1995, 'cluster_id__6': 6986, 'cluster_uid__7': 994, 'year__7': 2015, 'cluster_id__7': 6935, 'cluster_uid__8': 994, 'year__8': 2020, 'cluster_id__8': 6866, 'cluster_uid__9': 995, 'year__9': 2020, 'cluster_id__9': 7390, 'cluster_uid__10': 995, 'year__10': 1980, 'cluster_id__10': 7240, 'cluster_uid__11': 995, 'year__11': 1975, 'cluster_id__11': 7225, 'cluster_uid__12': 995, 'year__12': 2005, 'cluster_id__12': 7501, 'cluster_uid__13': 995, 'year__13': 2015, 'cluster_id__13': 7466, 'cluster_uid__14': 995, 'year__14': 1985, 'cluster_id__14': 7319, 'cluster_uid__15': 995, 'year__15': 1995, 'cluster_id__15': 7525, 'cluster_uid__16': 995, 'year__16': 1990 ... 2900 parameters truncated ... 'year__983': 1985, 'cluster_id__983': 879, 'cluster_uid__984': 1089, 'year__984': 1990, 'cluster_id__984': 912, 'cluster_uid__985': 1089, 'year__985': 2005, 'cluster_id__985': 932, 'cluster_uid__986': 1089, 'year__986': 2010, 'cluster_id__986': 930, 'cluster_uid__987': 1089, 'year__987': 1995, 'cluster_id__987': 931, 'cluster_uid__988': 1089, 'year__988': 2020, 'cluster_id__988': 921, 'cluster_uid__989': 1089, 'year__989': 1980, 'cluster_id__989': 891, 'cluster_uid__990': 1089, 'year__990': 2000, 'cluster_id__990': 934, 'cluster_uid__991': 1089, 'year__991': 1985, 'cluster_id__991': 902, 'cluster_uid__992': 1089, 'year__992': 1975, 'cluster_id__992': 889, 'cluster_uid__993': 1089, 'year__993': 2015, 'cluster_id__993': 924, 'cluster_uid__994': 1090, 'year__994': 1990, 'cluster_id__994': 1018, 'cluster_uid__995': 1090, 'year__995': 2015, 'cluster_id__995': 1021, 'cluster_uid__996': 1090, 'year__996': 2005, 'cluster_id__996': 1033, 'cluster_uid__997': 1090, 'year__997': 2010, 'cluster_id__997': 1027, 'cluster_uid__998': 1090, 'year__998': 1995, 'cluster_id__998': 1039, 'cluster_uid__999': 1090, 'year__999': 1980, 'cluster_id__999': 995}
# 2024-07-23 17:39:50,423 INFO sqlalchemy.engine.Engine INSERT INTO crosswalk_cluster_uid_to_cluster_id (cluster_uid, year, cluster_id) VALUES (%(cluster_uid__0)s, %(year__0)s, %(cluster_id__0)s), (%(cluster_uid__1)s, %(year__1)s, %(cluster_id__1)s), (%(cluster_uid__2)s, %(year__2)s, %(cluster_id__2)s), ( ... 59405 characters truncated ... 8)s, %(year__998)s, %(cluster_id__998)s), (%(cluster_uid__999)s, %(year__999)s, %(cluster_id__999)s)
# 2024-07-23 17:39:50,423 INFO sqlalchemy.engine.Engine [insertmanyvalues 12/967 (unordered)] {'cluster_uid__0': 1090, 'year__0': 1985, 'cluster_id__0': 1006, 'cluster_uid__1': 1090, 'year__1': 2020, 'cluster_id__1': 1011, 'cluster_uid__2': 1090, 'year__2': 2000, 'cluster_id__2': 1037, 'cluster_uid__3': 1090, 'year__3': 1975, 'cluster_id__3': 991, 'cluster_uid__4': 1091, 'year__4': 1985, 'cluster_id__4': 782, 'cluster_uid__5': 1091, 'year__5': 1995, 'cluster_id__5': 806, 'cluster_uid__6': 1091, 'year__6': 2015, 'cluster_id__6': 798, 'cluster_uid__7': 1091, 'year__7': 2005, 'cluster_id__7': 805, 'cluster_uid__8': 1091, 'year__8': 2020, 'cluster_id__8': 791, 'cluster_uid__9': 1091, 'year__9': 2010, 'cluster_id__9': 804, 'cluster_uid__10': 1091, 'year__10': 2000, 'cluster_id__10': 807, 'cluster_uid__11': 1091, 'year__11': 1980, 'cluster_id__11': 772, 'cluster_uid__12': 1091, 'year__12': 1990, 'cluster_id__12': 793, 'cluster_uid__13': 1091, 'year__13': 1975, 'cluster_id__13': 776, 'cluster_uid__14': 1092, 'year__14': 2005, 'cluster_id__14': 492, 'cluster_uid__15': 1092, 'year__15': 2020, 'cluster_id__15': 487, 'cluster_uid__16': 1092, 'year__16': 2010 ... 2900 parameters truncated ... 'year__983': 2005, 'cluster_id__983': 13732, 'cluster_uid__984': 1184, 'year__984': 1975, 'cluster_id__984': 13133, 'cluster_uid__985': 1184, 'year__985': 2005, 'cluster_id__985': 13734, 'cluster_uid__986': 1184, 'year__986': 1995, 'cluster_id__986': 13812, 'cluster_uid__987': 1184, 'year__987': 2005, 'cluster_id__987': 13733, 'cluster_uid__988': 1185, 'year__988': 1980, 'cluster_id__988': 6247, 'cluster_uid__989': 1185, 'year__989': 1975, 'cluster_id__989': 6230, 'cluster_uid__990': 1185, 'year__990': 2005, 'cluster_id__990': 6432, 'cluster_uid__991': 1185, 'year__991': 1995, 'cluster_id__991': 6473, 'cluster_uid__992': 1185, 'year__992': 1985, 'cluster_id__992': 6301, 'cluster_uid__993': 1185, 'year__993': 1990, 'cluster_id__993': 6373, 'cluster_uid__994': 1185, 'year__994': 2015, 'cluster_id__994': 6404, 'cluster_uid__995': 1185, 'year__995': 2000, 'cluster_id__995': 6474, 'cluster_uid__996': 1185, 'year__996': 2020, 'cluster_id__996': 6337, 'cluster_uid__997': 1185, 'year__997': 2010, 'cluster_id__997': 6398, 'cluster_uid__998': 1186, 'year__998': 2000, 'cluster_id__998': 14392, 'cluster_uid__999': 1186, 'year__999': 1975, 'cluster_id__999': 13693}
# 2024-07-23 17:39:50,433 INFO sqlalchemy.engine.Engine INSERT INTO crosswalk_cluster_uid_to_cluster_id (cluster_uid, year, cluster_id) VALUES (%(cluster_uid__0)s, %(year__0)s, %(cluster_id__0)s), (%(cluster_uid__1)s, %(year__1)s, %(cluster_id__1)s), (%(cluster_uid__2)s, %(year__2)s, %(cluster_id__2)s), ( ... 59405 characters truncated ... 8)s, %(year__998)s, %(cluster_id__998)s), (%(cluster_uid__999)s, %(year__999)s, %(cluster_id__999)s)
# 2024-07-23 17:39:50,433 INFO sqlalchemy.engine.Engine [insertmanyvalues 13/967 (unordered)] {'cluster_uid__0': 1186, 'year__0': 2015, 'cluster_id__0': 14438, 'cluster_uid__1': 1186, 'year__1': 1980, 'cluster_id__1': 13856, 'cluster_uid__2': 1186, 'year__2': 1985, 'cluster_id__2': 14016, 'cluster_uid__3': 1186, 'year__3': 1995, 'cluster_id__3': 14422, 'cluster_uid__4': 1186, 'year__4': 2020, 'cluster_id__4': 14263, 'cluster_uid__5': 1186, 'year__5': 2010, 'cluster_id__5': 14382, 'cluster_uid__6': 1186, 'year__6': 1990, 'cluster_id__6': 14222, 'cluster_uid__7': 1186, 'year__7': 2005, 'cluster_id__7': 14345, 'cluster_uid__8': 1187, 'year__8': 1990, 'cluster_id__8': 9581, 'cluster_uid__9': 1187, 'year__9': 2005, 'cluster_id__9': 9650, 'cluster_uid__10': 1187, 'year__10': 2015, 'cluster_id__10': 9595, 'cluster_uid__11': 1187, 'year__11': 2000, 'cluster_id__11': 9735, 'cluster_uid__12': 1187, 'year__12': 2005, 'cluster_id__12': 9649, 'cluster_uid__13': 1187, 'year__13': 2000, 'cluster_id__13': 9736, 'cluster_uid__14': 1187, 'year__14': 1975, 'cluster_id__14': 9343, 'cluster_uid__15': 1187, 'year__15': 1985, 'cluster_id__15': 9492, 'cluster_uid__16': 1187, 'year__16': 2020 ... 2900 parameters truncated ... 'year__983': 1975, 'cluster_id__983': 678, 'cluster_uid__984': 1277, 'year__984': 1990, 'cluster_id__984': 692, 'cluster_uid__985': 1277, 'year__985': 1980, 'cluster_id__985': 673, 'cluster_uid__986': 1277, 'year__986': 2015, 'cluster_id__986': 695, 'cluster_uid__987': 1277, 'year__987': 1985, 'cluster_id__987': 682, 'cluster_uid__988': 1278, 'year__988': 2010, 'cluster_id__988': 846, 'cluster_uid__989': 1278, 'year__989': 1995, 'cluster_id__989': 847, 'cluster_uid__990': 1278, 'year__990': 2005, 'cluster_id__990': 848, 'cluster_uid__991': 1278, 'year__991': 1975, 'cluster_id__991': 812, 'cluster_uid__992': 1278, 'year__992': 1990, 'cluster_id__992': 831, 'cluster_uid__993': 1278, 'year__993': 1980, 'cluster_id__993': 810, 'cluster_uid__994': 1278, 'year__994': 2000, 'cluster_id__994': 849, 'cluster_uid__995': 1278, 'year__995': 1985, 'cluster_id__995': 820, 'cluster_uid__996': 1278, 'year__996': 2020, 'cluster_id__996': 835, 'cluster_uid__997': 1278, 'year__997': 2015, 'cluster_id__997': 839, 'cluster_uid__998': 1279, 'year__998': 1995, 'cluster_id__998': 602, 'cluster_uid__999': 1279, 'year__999': 2010, 'cluster_id__999': 603}
# 2024-07-23 17:39:50,444 INFO sqlalchemy.engine.Engine INSERT INTO crosswalk_cluster_uid_to_cluster_id (cluster_uid, year, cluster_id) VALUES (%(cluster_uid__0)s, %(year__0)s, %(cluster_id__0)s), (%(cluster_uid__1)s, %(year__1)s, %(cluster_id__1)s), (%(cluster_uid__2)s, %(year__2)s, %(cluster_id__2)s), ( ... 59405 characters truncated ... 8)s, %(year__998)s, %(cluster_id__998)s), (%(cluster_uid__999)s, %(year__999)s, %(cluster_id__999)s)
# 2024-07-23 17:39:50,444 INFO sqlalchemy.engine.Engine [insertmanyvalues 14/967 (unordered)] {'cluster_uid__0': 1279, 'year__0': 1990, 'cluster_id__0': 590, 'cluster_uid__1': 1279, 'year__1': 1980, 'cluster_id__1': 579, 'cluster_uid__2': 1279, 'year__2': 2000, 'cluster_id__2': 603, 'cluster_uid__3': 1279, 'year__3': 2005, 'cluster_id__3': 603, 'cluster_uid__4': 1279, 'year__4': 1985, 'cluster_id__4': 582, 'cluster_uid__5': 1279, 'year__5': 2020, 'cluster_id__5': 593, 'cluster_uid__6': 1279, 'year__6': 2015, 'cluster_id__6': 597, 'cluster_uid__7': 1279, 'year__7': 1975, 'cluster_id__7': 579, 'cluster_uid__8': 1280, 'year__8': 2010, 'cluster_id__8': 198, 'cluster_uid__9': 1280, 'year__9': 1980, 'cluster_id__9': 195, 'cluster_uid__10': 1280, 'year__10': 2000, 'cluster_id__10': 199, 'cluster_uid__11': 1280, 'year__11': 2015, 'cluster_id__11': 196, 'cluster_uid__12': 1280, 'year__12': 1995, 'cluster_id__12': 205, 'cluster_uid__13': 1280, 'year__13': 2005, 'cluster_id__13': 199, 'cluster_uid__14': 1280, 'year__14': 1975, 'cluster_id__14': 198, 'cluster_uid__15': 1280, 'year__15': 1990, 'cluster_id__15': 198, 'cluster_uid__16': 1280, 'year__16': 1985 ... 2900 parameters truncated ... 'year__983': 2010, 'cluster_id__983': 419, 'cluster_uid__984': 1372, 'year__984': 1990, 'cluster_id__984': 401, 'cluster_uid__985': 1372, 'year__985': 2015, 'cluster_id__985': 418, 'cluster_uid__986': 1372, 'year__986': 2020, 'cluster_id__986': 411, 'cluster_uid__987': 1372, 'year__987': 1975, 'cluster_id__987': 395, 'cluster_uid__988': 1372, 'year__988': 1995, 'cluster_id__988': 414, 'cluster_uid__989': 1372, 'year__989': 2000, 'cluster_id__989': 416, 'cluster_uid__990': 1372, 'year__990': 1985, 'cluster_id__990': 398, 'cluster_uid__991': 1373, 'year__991': 1995, 'cluster_id__991': 223, 'cluster_uid__992': 1373, 'year__992': 2010, 'cluster_id__992': 215, 'cluster_uid__993': 1373, 'year__993': 1990, 'cluster_id__993': 216, 'cluster_uid__994': 1373, 'year__994': 2005, 'cluster_id__994': 216, 'cluster_uid__995': 1373, 'year__995': 2020, 'cluster_id__995': 211, 'cluster_uid__996': 1373, 'year__996': 2000, 'cluster_id__996': 218, 'cluster_uid__997': 1373, 'year__997': 2015, 'cluster_id__997': 213, 'cluster_uid__998': 1373, 'year__998': 1980, 'cluster_id__998': 213, 'cluster_uid__999': 1373, 'year__999': 1975, 'cluster_id__999': 216}
# 2024-07-23 17:39:50,456 INFO sqlalchemy.engine.Engine INSERT INTO crosswalk_cluster_uid_to_cluster_id (cluster_uid, year, cluster_id) VALUES (%(cluster_uid__0)s, %(year__0)s, %(cluster_id__0)s), (%(cluster_uid__1)s, %(year__1)s, %(cluster_id__1)s), (%(cluster_uid__2)s, %(year__2)s, %(cluster_id__2)s), ( ... 59405 characters truncated ... 8)s, %(year__998)s, %(cluster_id__998)s), (%(cluster_uid__999)s, %(year__999)s, %(cluster_id__999)s)
# 2024-07-23 17:39:50,456 INFO sqlalchemy.engine.Engine [insertmanyvalues 15/967 (unordered)] {'cluster_uid__0': 1373, 'year__0': 1985, 'cluster_id__0': 215, 'cluster_uid__1': 1374, 'year__1': 1995, 'cluster_id__1': 1008, 'cluster_uid__2': 1374, 'year__2': 1985, 'cluster_id__2': 974, 'cluster_uid__3': 1374, 'year__3': 1990, 'cluster_id__3': 987, 'cluster_uid__4': 1374, 'year__4': 2010, 'cluster_id__4': 1001, 'cluster_uid__5': 1374, 'year__5': 1980, 'cluster_id__5': 962, 'cluster_uid__6': 1374, 'year__6': 1975, 'cluster_id__6': 958, 'cluster_uid__7': 1374, 'year__7': 2015, 'cluster_id__7': 995, 'cluster_uid__8': 1374, 'year__8': 2000, 'cluster_id__8': 1007, 'cluster_uid__9': 1374, 'year__9': 2020, 'cluster_id__9': 989, 'cluster_uid__10': 1374, 'year__10': 2005, 'cluster_id__10': 1005, 'cluster_uid__11': 1375, 'year__11': 1990, 'cluster_id__11': 905, 'cluster_uid__12': 1375, 'year__12': 1985, 'cluster_id__12': 895, 'cluster_uid__13': 1375, 'year__13': 2015, 'cluster_id__13': 917, 'cluster_uid__14': 1375, 'year__14': 2000, 'cluster_id__14': 927, 'cluster_uid__15': 1375, 'year__15': 2010, 'cluster_id__15': 923, 'cluster_uid__16': 1375, 'year__16': 1975 ... 2900 parameters truncated ... 'year__983': 2000, 'cluster_id__983': 877, 'cluster_uid__984': 1454, 'year__984': 1985, 'cluster_id__984': 846, 'cluster_uid__985': 1454, 'year__985': 1980, 'cluster_id__985': 835, 'cluster_uid__986': 1455, 'year__986': 1990, 'cluster_id__986': 25, 'cluster_uid__987': 1455, 'year__987': 1975, 'cluster_id__987': 25, 'cluster_uid__988': 1455, 'year__988': 1980, 'cluster_id__988': 25, 'cluster_uid__989': 1455, 'year__989': 2020, 'cluster_id__989': 25, 'cluster_uid__990': 1455, 'year__990': 1985, 'cluster_id__990': 25, 'cluster_uid__991': 1455, 'year__991': 2000, 'cluster_id__991': 25, 'cluster_uid__992': 1455, 'year__992': 2010, 'cluster_id__992': 24, 'cluster_uid__993': 1455, 'year__993': 2005, 'cluster_id__993': 24, 'cluster_uid__994': 1455, 'year__994': 1995, 'cluster_id__994': 25, 'cluster_uid__995': 1455, 'year__995': 2015, 'cluster_id__995': 24, 'cluster_uid__996': 1456, 'year__996': 1975, 'cluster_id__996': 141, 'cluster_uid__997': 1456, 'year__997': 1985, 'cluster_id__997': 138, 'cluster_uid__998': 1456, 'year__998': 1980, 'cluster_id__998': 137, 'cluster_uid__999': 1456, 'year__999': 2000, 'cluster_id__999': 139}
# 2024-07-23 17:39:50,466 INFO sqlalchemy.engine.Engine INSERT INTO crosswalk_cluster_uid_to_cluster_id (cluster_uid, year, cluster_id) VALUES (%(cluster_uid__0)s, %(year__0)s, %(cluster_id__0)s), (%(cluster_uid__1)s, %(year__1)s, %(cluster_id__1)s), (%(cluster_uid__2)s, %(year__2)s, %(cluster_id__2)s), ( ... 59405 characters truncated ... 8)s, %(year__998)s, %(cluster_id__998)s), (%(cluster_uid__999)s, %(year__999)s, %(cluster_id__999)s)
# 2024-07-23 17:39:50,466 INFO sqlalchemy.engine.Engine [insertmanyvalues 16/967 (unordered)] {'cluster_uid__0': 1456, 'year__0': 2015, 'cluster_id__0': 134, 'cluster_uid__1': 1456, 'year__1': 2020, 'cluster_id__1': 133, 'cluster_uid__2': 1456, 'year__2': 1990, 'cluster_id__2': 140, 'cluster_uid__3': 1456, 'year__3': 2005, 'cluster_id__3': 136, 'cluster_uid__4': 1456, 'year__4': 1995, 'cluster_id__4': 144, 'cluster_uid__5': 1456, 'year__5': 2010, 'cluster_id__5': 134, 'cluster_uid__6': 1457, 'year__6': 2020, 'cluster_id__6': 107, 'cluster_uid__7': 1457, 'year__7': 2000, 'cluster_id__7': 116, 'cluster_uid__8': 1457, 'year__8': 1980, 'cluster_id__8': 119, 'cluster_uid__9': 1457, 'year__9': 1995, 'cluster_id__9': 120, 'cluster_uid__10': 1457, 'year__10': 2015, 'cluster_id__10': 107, 'cluster_uid__11': 1457, 'year__11': 1975, 'cluster_id__11': 122, 'cluster_uid__12': 1457, 'year__12': 1990, 'cluster_id__12': 119, 'cluster_uid__13': 1457, 'year__13': 1985, 'cluster_id__13': 119, 'cluster_uid__14': 1457, 'year__14': 2010, 'cluster_id__14': 107, 'cluster_uid__15': 1457, 'year__15': 2005, 'cluster_id__15': 113, 'cluster_uid__16': 1458, 'year__16': 1975 ... 2900 parameters truncated ... 'year__983': 1980, 'cluster_id__983': 18551, 'cluster_uid__984': 1550, 'year__984': 1985, 'cluster_id__984': 18868, 'cluster_uid__985': 1550, 'year__985': 1975, 'cluster_id__985': 18267, 'cluster_uid__986': 1551, 'year__986': 2010, 'cluster_id__986': 2471, 'cluster_uid__987': 1551, 'year__987': 2000, 'cluster_id__987': 2507, 'cluster_uid__988': 1551, 'year__988': 2005, 'cluster_id__988': 2478, 'cluster_uid__989': 1551, 'year__989': 2015, 'cluster_id__989': 2480, 'cluster_uid__990': 1551, 'year__990': 1985, 'cluster_id__990': 2435, 'cluster_uid__991': 1551, 'year__991': 1980, 'cluster_id__991': 2415, 'cluster_uid__992': 1551, 'year__992': 1990, 'cluster_id__992': 2455, 'cluster_uid__993': 1551, 'year__993': 1975, 'cluster_id__993': 2399, 'cluster_uid__994': 1551, 'year__994': 2020, 'cluster_id__994': 2468, 'cluster_uid__995': 1551, 'year__995': 1995, 'cluster_id__995': 2511, 'cluster_uid__996': 1552, 'year__996': 1990, 'cluster_id__996': 12478, 'cluster_uid__997': 1552, 'year__997': 1985, 'cluster_id__997': 12299, 'cluster_uid__998': 1552, 'year__998': 1980, 'cluster_id__998': 12157, 'cluster_uid__999': 1552, 'year__999': 1975, 'cluster_id__999': 12032}
# 2024-07-23 17:39:50,476 INFO sqlalchemy.engine.Engine INSERT INTO crosswalk_cluster_uid_to_cluster_id (cluster_uid, year, cluster_id) VALUES (%(cluster_uid__0)s, %(year__0)s, %(cluster_id__0)s), (%(cluster_uid__1)s, %(year__1)s, %(cluster_id__1)s), (%(cluster_uid__2)s, %(year__2)s, %(cluster_id__2)s), ( ... 59405 characters truncated ... 8)s, %(year__998)s, %(cluster_id__998)s), (%(cluster_uid__999)s, %(year__999)s, %(cluster_id__999)s)
# ...
# 2024-07-23 17:39:59,067 INFO sqlalchemy.engine.Engine INSERT INTO crosswalk_cluster_uid_to_cluster_id (cluster_uid, year, cluster_id) VALUES (%(cluster_uid__0)s, %(year__0)s, %(cluster_id__0)s), (%(cluster_uid__1)s, %(year__1)s, %(cluster_id__1)s), (%(cluster_uid__2)s, %(year__2)s, %(cluster_id__2)s), ( ... 59405 characters truncated ... 8)s, %(year__998)s, %(cluster_id__998)s), (%(cluster_uid__999)s, %(year__999)s, %(cluster_id__999)s)
# 2024-07-23 17:39:59,067 INFO sqlalchemy.engine.Engine [insertmanyvalues 963/967 (unordered)] {'cluster_uid__0': 127594, 'year__0': 2020, 'cluster_id__0': 77581, 'cluster_uid__1': 127595, 'year__1': 2020, 'cluster_id__1': 58936, 'cluster_uid__2': 127596, 'year__2': 2020, 'cluster_id__2': 94907, 'cluster_uid__3': 127597, 'year__3': 2020, 'cluster_id__3': 35223, 'cluster_uid__4': 127598, 'year__4': 2020, 'cluster_id__4': 59600, 'cluster_uid__5': 127599, 'year__5': 2020, 'cluster_id__5': 49336, 'cluster_uid__6': 127600, 'year__6': 2020, 'cluster_id__6': 99541, 'cluster_uid__7': 127601, 'year__7': 2020, 'cluster_id__7': 78885, 'cluster_uid__8': 127602, 'year__8': 2020, 'cluster_id__8': 88017, 'cluster_uid__9': 127603, 'year__9': 2020, 'cluster_id__9': 25030, 'cluster_uid__10': 127604, 'year__10': 2020, 'cluster_id__10': 65746, 'cluster_uid__11': 127605, 'year__11': 2020, 'cluster_id__11': 99513, 'cluster_uid__12': 127606, 'year__12': 2020, 'cluster_id__12': 95809, 'cluster_uid__13': 127607, 'year__13': 2020, 'cluster_id__13': 24421, 'cluster_uid__14': 127608, 'year__14': 2020, 'cluster_id__14': 75084, 'cluster_uid__15': 127609, 'year__15': 2020, 'cluster_id__15': 42548, 'cluster_uid__16': 127610, 'year__16': 2020 ... 2900 parameters truncated ... 'year__983': 2020, 'cluster_id__983': 32013, 'cluster_uid__984': 128578, 'year__984': 2020, 'cluster_id__984': 83618, 'cluster_uid__985': 128579, 'year__985': 2020, 'cluster_id__985': 44125, 'cluster_uid__986': 128580, 'year__986': 2020, 'cluster_id__986': 83433, 'cluster_uid__987': 128581, 'year__987': 2020, 'cluster_id__987': 69402, 'cluster_uid__988': 128582, 'year__988': 2020, 'cluster_id__988': 80194, 'cluster_uid__989': 128583, 'year__989': 2020, 'cluster_id__989': 63131, 'cluster_uid__990': 128584, 'year__990': 2020, 'cluster_id__990': 91534, 'cluster_uid__991': 128585, 'year__991': 2020, 'cluster_id__991': 18222, 'cluster_uid__992': 128586, 'year__992': 2020, 'cluster_id__992': 31138, 'cluster_uid__993': 128587, 'year__993': 2020, 'cluster_id__993': 99702, 'cluster_uid__994': 128588, 'year__994': 2020, 'cluster_id__994': 33454, 'cluster_uid__995': 128589, 'year__995': 2020, 'cluster_id__995': 26426, 'cluster_uid__996': 128590, 'year__996': 2020, 'cluster_id__996': 50169, 'cluster_uid__997': 128591, 'year__997': 2020, 'cluster_id__997': 83558, 'cluster_uid__998': 128592, 'year__998': 2020, 'cluster_id__998': 76524, 'cluster_uid__999': 128593, 'year__999': 2020, 'cluster_id__999': 88356}
# 2024-07-23 17:39:59,073 INFO sqlalchemy.engine.Engine INSERT INTO crosswalk_cluster_uid_to_cluster_id (cluster_uid, year, cluster_id) VALUES (%(cluster_uid__0)s, %(year__0)s, %(cluster_id__0)s), (%(cluster_uid__1)s, %(year__1)s, %(cluster_id__1)s), (%(cluster_uid__2)s, %(year__2)s, %(cluster_id__2)s), ( ... 59405 characters truncated ... 8)s, %(year__998)s, %(cluster_id__998)s), (%(cluster_uid__999)s, %(year__999)s, %(cluster_id__999)s)
# 2024-07-23 17:39:59,073 INFO sqlalchemy.engine.Engine [insertmanyvalues 964/967 (unordered)] {'cluster_uid__0': 128594, 'year__0': 2020, 'cluster_id__0': 28183, 'cluster_uid__1': 128595, 'year__1': 2020, 'cluster_id__1': 98183, 'cluster_uid__2': 128596, 'year__2': 2020, 'cluster_id__2': 94781, 'cluster_uid__3': 128597, 'year__3': 2020, 'cluster_id__3': 92387, 'cluster_uid__4': 128598, 'year__4': 2020, 'cluster_id__4': 29268, 'cluster_uid__5': 128599, 'year__5': 2020, 'cluster_id__5': 91211, 'cluster_uid__6': 128600, 'year__6': 2020, 'cluster_id__6': 64093, 'cluster_uid__7': 128601, 'year__7': 2020, 'cluster_id__7': 49385, 'cluster_uid__8': 128602, 'year__8': 2020, 'cluster_id__8': 21533, 'cluster_uid__9': 128603, 'year__9': 2020, 'cluster_id__9': 86732, 'cluster_uid__10': 128604, 'year__10': 2020, 'cluster_id__10': 81143, 'cluster_uid__11': 128605, 'year__11': 2020, 'cluster_id__11': 67232, 'cluster_uid__12': 128606, 'year__12': 2020, 'cluster_id__12': 96676, 'cluster_uid__13': 128607, 'year__13': 2020, 'cluster_id__13': 17509, 'cluster_uid__14': 128608, 'year__14': 2020, 'cluster_id__14': 35869, 'cluster_uid__15': 128609, 'year__15': 2020, 'cluster_id__15': 52812, 'cluster_uid__16': 128610, 'year__16': 2020 ... 2900 parameters truncated ... 'year__983': 2020, 'cluster_id__983': 78355, 'cluster_uid__984': 129578, 'year__984': 2020, 'cluster_id__984': 58161, 'cluster_uid__985': 129579, 'year__985': 2020, 'cluster_id__985': 71243, 'cluster_uid__986': 129580, 'year__986': 2020, 'cluster_id__986': 19094, 'cluster_uid__987': 129581, 'year__987': 2020, 'cluster_id__987': 63173, 'cluster_uid__988': 129582, 'year__988': 2020, 'cluster_id__988': 71405, 'cluster_uid__989': 129583, 'year__989': 2020, 'cluster_id__989': 95939, 'cluster_uid__990': 129584, 'year__990': 2020, 'cluster_id__990': 67459, 'cluster_uid__991': 129585, 'year__991': 2020, 'cluster_id__991': 94191, 'cluster_uid__992': 129586, 'year__992': 2020, 'cluster_id__992': 77911, 'cluster_uid__993': 129587, 'year__993': 2020, 'cluster_id__993': 21946, 'cluster_uid__994': 129588, 'year__994': 2020, 'cluster_id__994': 49026, 'cluster_uid__995': 129589, 'year__995': 2020, 'cluster_id__995': 48588, 'cluster_uid__996': 129590, 'year__996': 2020, 'cluster_id__996': 74021, 'cluster_uid__997': 129591, 'year__997': 2020, 'cluster_id__997': 56707, 'cluster_uid__998': 129592, 'year__998': 2020, 'cluster_id__998': 94943, 'cluster_uid__999': 129593, 'year__999': 2020, 'cluster_id__999': 95269}
# 2024-07-23 17:39:59,083 INFO sqlalchemy.engine.Engine INSERT INTO crosswalk_cluster_uid_to_cluster_id (cluster_uid, year, cluster_id) VALUES (%(cluster_uid__0)s, %(year__0)s, %(cluster_id__0)s), (%(cluster_uid__1)s, %(year__1)s, %(cluster_id__1)s), (%(cluster_uid__2)s, %(year__2)s, %(cluster_id__2)s), ( ... 59405 characters truncated ... 8)s, %(year__998)s, %(cluster_id__998)s), (%(cluster_uid__999)s, %(year__999)s, %(cluster_id__999)s)
# 2024-07-23 17:39:59,083 INFO sqlalchemy.engine.Engine [insertmanyvalues 965/967 (unordered)] {'cluster_uid__0': 129594, 'year__0': 2020, 'cluster_id__0': 100768, 'cluster_uid__1': 129595, 'year__1': 2020, 'cluster_id__1': 83015, 'cluster_uid__2': 129596, 'year__2': 2020, 'cluster_id__2': 56476, 'cluster_uid__3': 129597, 'year__3': 2020, 'cluster_id__3': 98327, 'cluster_uid__4': 129598, 'year__4': 2020, 'cluster_id__4': 75106, 'cluster_uid__5': 129599, 'year__5': 2020, 'cluster_id__5': 46216, 'cluster_uid__6': 129600, 'year__6': 2020, 'cluster_id__6': 49824, 'cluster_uid__7': 129601, 'year__7': 2020, 'cluster_id__7': 56513, 'cluster_uid__8': 129602, 'year__8': 2020, 'cluster_id__8': 83569, 'cluster_uid__9': 129603, 'year__9': 2020, 'cluster_id__9': 55219, 'cluster_uid__10': 129604, 'year__10': 2020, 'cluster_id__10': 109969, 'cluster_uid__11': 129605, 'year__11': 2020, 'cluster_id__11': 78267, 'cluster_uid__12': 129606, 'year__12': 2020, 'cluster_id__12': 78843, 'cluster_uid__13': 129607, 'year__13': 2020, 'cluster_id__13': 68942, 'cluster_uid__14': 129608, 'year__14': 2020, 'cluster_id__14': 61597, 'cluster_uid__15': 129609, 'year__15': 2020, 'cluster_id__15': 18767, 'cluster_uid__16': 129610, 'year__16': 2020 ... 2900 parameters truncated ... 'year__983': 2020, 'cluster_id__983': 71041, 'cluster_uid__984': 130578, 'year__984': 2020, 'cluster_id__984': 84015, 'cluster_uid__985': 130579, 'year__985': 2020, 'cluster_id__985': 51437, 'cluster_uid__986': 130580, 'year__986': 2020, 'cluster_id__986': 64748, 'cluster_uid__987': 130581, 'year__987': 2020, 'cluster_id__987': 90142, 'cluster_uid__988': 130582, 'year__988': 2020, 'cluster_id__988': 101174, 'cluster_uid__989': 130583, 'year__989': 2020, 'cluster_id__989': 71484, 'cluster_uid__990': 130584, 'year__990': 2020, 'cluster_id__990': 79060, 'cluster_uid__991': 130585, 'year__991': 2020, 'cluster_id__991': 107924, 'cluster_uid__992': 130586, 'year__992': 2020, 'cluster_id__992': 100995, 'cluster_uid__993': 130587, 'year__993': 2020, 'cluster_id__993': 62579, 'cluster_uid__994': 130588, 'year__994': 2020, 'cluster_id__994': 44260, 'cluster_uid__995': 130589, 'year__995': 2020, 'cluster_id__995': 70900, 'cluster_uid__996': 130590, 'year__996': 2020, 'cluster_id__996': 57296, 'cluster_uid__997': 130591, 'year__997': 2020, 'cluster_id__997': 46237, 'cluster_uid__998': 130592, 'year__998': 2020, 'cluster_id__998': 102685, 'cluster_uid__999': 130593, 'year__999': 2020, 'cluster_id__999': 50607}
# 2024-07-23 17:39:59,093 INFO sqlalchemy.engine.Engine INSERT INTO crosswalk_cluster_uid_to_cluster_id (cluster_uid, year, cluster_id) VALUES (%(cluster_uid__0)s, %(year__0)s, %(cluster_id__0)s), (%(cluster_uid__1)s, %(year__1)s, %(cluster_id__1)s), (%(cluster_uid__2)s, %(year__2)s, %(cluster_id__2)s), ( ... 59405 characters truncated ... 8)s, %(year__998)s, %(cluster_id__998)s), (%(cluster_uid__999)s, %(year__999)s, %(cluster_id__999)s)
# 2024-07-23 17:39:59,093 INFO sqlalchemy.engine.Engine [insertmanyvalues 966/967 (unordered)] {'cluster_uid__0': 130594, 'year__0': 2020, 'cluster_id__0': 101029, 'cluster_uid__1': 130595, 'year__1': 2020, 'cluster_id__1': 83770, 'cluster_uid__2': 130596, 'year__2': 2020, 'cluster_id__2': 26786, 'cluster_uid__3': 130597, 'year__3': 2020, 'cluster_id__3': 42326, 'cluster_uid__4': 130598, 'year__4': 2020, 'cluster_id__4': 81280, 'cluster_uid__5': 130599, 'year__5': 2020, 'cluster_id__5': 87005, 'cluster_uid__6': 130600, 'year__6': 2020, 'cluster_id__6': 78978, 'cluster_uid__7': 130601, 'year__7': 2020, 'cluster_id__7': 40001, 'cluster_uid__8': 130602, 'year__8': 2020, 'cluster_id__8': 36298, 'cluster_uid__9': 130603, 'year__9': 2020, 'cluster_id__9': 97463, 'cluster_uid__10': 130604, 'year__10': 2020, 'cluster_id__10': 105089, 'cluster_uid__11': 130605, 'year__11': 2020, 'cluster_id__11': 58893, 'cluster_uid__12': 130606, 'year__12': 2020, 'cluster_id__12': 92818, 'cluster_uid__13': 130607, 'year__13': 2020, 'cluster_id__13': 74995, 'cluster_uid__14': 130608, 'year__14': 2020, 'cluster_id__14': 67858, 'cluster_uid__15': 130609, 'year__15': 2020, 'cluster_id__15': 42971, 'cluster_uid__16': 130610, 'year__16': 2020 ... 2900 parameters truncated ... 'year__983': 2020, 'cluster_id__983': 84150, 'cluster_uid__984': 131578, 'year__984': 2020, 'cluster_id__984': 64016, 'cluster_uid__985': 131579, 'year__985': 2020, 'cluster_id__985': 90617, 'cluster_uid__986': 131580, 'year__986': 2020, 'cluster_id__986': 31839, 'cluster_uid__987': 131581, 'year__987': 2020, 'cluster_id__987': 102230, 'cluster_uid__988': 131582, 'year__988': 2020, 'cluster_id__988': 50192, 'cluster_uid__989': 131583, 'year__989': 2020, 'cluster_id__989': 48810, 'cluster_uid__990': 131584, 'year__990': 2020, 'cluster_id__990': 70248, 'cluster_uid__991': 131585, 'year__991': 2020, 'cluster_id__991': 37548, 'cluster_uid__992': 131586, 'year__992': 2020, 'cluster_id__992': 60663, 'cluster_uid__993': 131587, 'year__993': 2020, 'cluster_id__993': 61162, 'cluster_uid__994': 131588, 'year__994': 2020, 'cluster_id__994': 52086, 'cluster_uid__995': 131589, 'year__995': 2020, 'cluster_id__995': 93847, 'cluster_uid__996': 131590, 'year__996': 2020, 'cluster_id__996': 74469, 'cluster_uid__997': 131591, 'year__997': 2020, 'cluster_id__997': 103268, 'cluster_uid__998': 131592, 'year__998': 2020, 'cluster_id__998': 79424, 'cluster_uid__999': 131593, 'year__999': 2020, 'cluster_id__999': 79215}
# 2024-07-23 17:39:59,101 INFO sqlalchemy.engine.Engine INSERT INTO crosswalk_cluster_uid_to_cluster_id (cluster_uid, year, cluster_id) VALUES (%(cluster_uid__0)s, %(year__0)s, %(cluster_id__0)s), (%(cluster_uid__1)s, %(year__1)s, %(cluster_id__1)s), (%(cluster_uid__2)s, %(year__2)s, %(cluster_id__2)s), ( ... 5585 characters truncated ... 1)s, %(year__101)s, %(cluster_id__101)s), (%(cluster_uid__102)s, %(year__102)s, %(cluster_id__102)s)
# 2024-07-23 17:39:59,101 INFO sqlalchemy.engine.Engine [insertmanyvalues 967/967 (unordered)] {'cluster_uid__0': 131594, 'year__0': 2020, 'cluster_id__0': 21903, 'cluster_uid__1': 131595, 'year__1': 2020, 'cluster_id__1': 74732, 'cluster_uid__2': 131596, 'year__2': 2020, 'cluster_id__2': 78794, 'cluster_uid__3': 131597, 'year__3': 2020, 'cluster_id__3': 102697, 'cluster_uid__4': 131598, 'year__4': 2020, 'cluster_id__4': 94627, 'cluster_uid__5': 131599, 'year__5': 2020, 'cluster_id__5': 35545, 'cluster_uid__6': 131600, 'year__6': 2020, 'cluster_id__6': 63643, 'cluster_uid__7': 131601, 'year__7': 2020, 'cluster_id__7': 63791, 'cluster_uid__8': 131602, 'year__8': 2020, 'cluster_id__8': 26570, 'cluster_uid__9': 131603, 'year__9': 2020, 'cluster_id__9': 93340, 'cluster_uid__10': 131604, 'year__10': 2020, 'cluster_id__10': 94819, 'cluster_uid__11': 131605, 'year__11': 2020, 'cluster_id__11': 99833, 'cluster_uid__12': 131606, 'year__12': 2020, 'cluster_id__12': 19441, 'cluster_uid__13': 131607, 'year__13': 2020, 'cluster_id__13': 42491, 'cluster_uid__14': 131608, 'year__14': 2020, 'cluster_id__14': 44296, 'cluster_uid__15': 131609, 'year__15': 2020, 'cluster_id__15': 71402, 'cluster_uid__16': 131610, 'year__16': 2020 ... 209 parameters truncated ... 'year__86': 2020, 'cluster_id__86': 60533, 'cluster_uid__87': 131681, 'year__87': 2020, 'cluster_id__87': 83740, 'cluster_uid__88': 131682, 'year__88': 2020, 'cluster_id__88': 86503, 'cluster_uid__89': 131683, 'year__89': 2020, 'cluster_id__89': 97501, 'cluster_uid__90': 131684, 'year__90': 2020, 'cluster_id__90': 49526, 'cluster_uid__91': 131685, 'year__91': 2020, 'cluster_id__91': 96938, 'cluster_uid__92': 131686, 'year__92': 2020, 'cluster_id__92': 78861, 'cluster_uid__93': 131687, 'year__93': 2020, 'cluster_id__93': 50028, 'cluster_uid__94': 131688, 'year__94': 2020, 'cluster_id__94': 63806, 'cluster_uid__95': 131689, 'year__95': 2020, 'cluster_id__95': 98214, 'cluster_uid__96': 131690, 'year__96': 2020, 'cluster_id__96': 41902, 'cluster_uid__97': 131691, 'year__97': 2020, 'cluster_id__97': 49414, 'cluster_uid__98': 131692, 'year__98': 2020, 'cluster_id__98': 41777, 'cluster_uid__99': 131693, 'year__99': 2020, 'cluster_id__99': 45863, 'cluster_uid__100': 131694, 'year__100': 2020, 'cluster_id__100': 50997, 'cluster_uid__101': 131695, 'year__101': 2020, 'cluster_id__101': 23589, 'cluster_uid__102': 131696, 'year__102': 2020, 'cluster_id__102': 74991}
# 2024-07-23 17:39:59,183 INFO sqlalchemy.engine.Engine COMMIT

# %%
tcc.create_time_consistent_cluster_pre_geocoding()
# Out:
# 2024-07-23 23:14:46,333 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-07-23 23:14:46,334 INFO sqlalchemy.engine.Engine DROP TABLE IF EXISTS "time_consistent_cluster_pre_geocoding";
# DROP TABLE IF EXISTS "time_consistent_cluster_geometry_pre_geocoding";
#
# -- Create the time consistent cluster geometry table
# CREATE TABLE "time_consistent_cluster_geometry_pre_geocoding" AS
# WITH multiyear_cluster_with_uid AS (
#     SELECT m.cluster_uid, c.year, c.cluster_id, geom
#     FROM "crosswalk_cluster_uid_to_cluster_id" m JOIN "multiyear_cluster" c
#     ON m.cluster_id = c.cluster_id AND m.year = c.year
# )
# SELECT cluster_uid, ST_Union(geom) AS geom
# FROM multiyear_cluster_with_uid
# GROUP BY cluster_uid;
#
# CREATE INDEX ON "time_consistent_cluster_geometry_pre_geocoding" USING GIST (geom);
#
# -- Create the time consistent cluster table
# CREATE TABLE "time_consistent_cluster_pre_geocoding" AS
# WITH multiyear_cluster_with_uid AS (
#     SELECT m.cluster_uid, c.year, c.cluster_id, population
#     FROM "crosswalk_cluster_uid_to_cluster_id" m JOIN "multiyear_cluster" c
#     ON m.cluster_id = c.cluster_id AND m.year = c.year
# )
# SELECT cluster_uid, year, SUM(population) AS population
# FROM multiyear_cluster_with_uid
# GROUP BY cluster_uid, year;
# 2024-07-23 23:14:46,335 INFO sqlalchemy.engine.Engine [generated in 0.00029s] {}
# 2024-07-23 23:15:34,480 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# # 4. Country Geocoding
# Here we load the country boarder data and assign to each cluster, year pair the country that the cluster belongs into the given year.
# - 4.1 Load the country boarder data
# - 4.2 Assign the country to each cluster, year pair. Here we make a couple of choices thar are worth noting:
#     - Border clusters are assigned to the country with the largest area of intersection
#     - Small islands that intersect no country are removed. These are typically islands so small that they are not counted in the country border dataset.

# %%
tcc.load_country_borders()
# Out:
# 2024-07-23 23:15:46,253 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-07-23 23:15:46,254 INFO sqlalchemy.engine.Engine DROP TABLE IF EXISTS country_borders
# 2024-07-23 23:15:46,254 INFO sqlalchemy.engine.Engine [cached since 950.1s ago] {}
# 2024-07-23 23:15:46,257 INFO sqlalchemy.engine.Engine DROP TABLE IF EXISTS crosswalk_cshape_to_world_bank_codes
# 2024-07-23 23:15:46,257 INFO sqlalchemy.engine.Engine [cached since 950.1s ago] {}
# 2024-07-23 23:15:46,259 INFO sqlalchemy.engine.Engine COMMIT
# Running bash script with arguments:
# CREATE TABLE
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# ALTER TABLE
# CREATE TABLE
# COPY 185
# Data loaded successfully.
# Return code: 0

# %%
tcc.geocode_cluster_with_country()
# Out:
# 2024-07-23 23:20:32,480 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-07-23 23:20:32,483 INFO sqlalchemy.engine.Engine DROP TABLE IF EXISTS time_consistent_cluster;
# DROP TABLE IF EXISTS time_consistent_cluster_geometry;
#
# -- Temporary table of transformed country borders
# CREATE TEMPORARY TABLE temp_country_geom_transformed ON COMMIT DROP AS
# SELECT gwcode, gwsyear, gweyear, ST_transform(the_geom, 54009) AS geom
# FROM country_borders;
#
# CREATE INDEX ON temp_country_geom_transformed USING GIST (geom);
#
# -- Temporary table of cluster-country matching
# CREATE TEMPORARY TABLE temp_cluster_country_matching ON COMMIT DROP AS
# SELECT cluster_uid, year, gwcode, gwsyear, gweyear
# FROM (time_consistent_cluster_pre_geocoding JOIN time_consistent_cluster_geometry_pre_geocoding USING (cluster_uid)) cluster
# JOIN temp_country_geom_transformed country ON st_intersects(cluster.geom, country.geom)
# WHERE (gwsyear < year AND year <= gweyear) OR (year = 2020 AND gweyear = 2019);
#
# -- Temporary table of clusters that match with multiple countries (i.e., border clusters)
# CREATE TEMPORARY TABLE temp_cluster_country_matching_multiple_countries ON COMMIT DROP AS
# WITH countries_matched_per_cluster AS (
#     SELECT cluster_uid, year, COUNT(*) AS n_matched_countries
#     FROM temp_cluster_country_matching
#     GROUP BY cluster_uid, year
# ),
# clusters_matched_with_multiple_countries AS (
#   SELECT cluster_uid, year, gwcode, gwsyear, gweyear
#   FROM temp_cluster_country_matching JOIN (SELECT * FROM countries_matched_per_cluster WHERE n_matched_countries >= 2) USING (cluster_uid, year)
# ),
# cluster_country_intersection_areas AS (
#     SELECT cluster_uid, year, gwcode, ST_Area(ST_Intersection(cluster.geom, country.geom)) AS intersection_area
#     FROM clusters_matched_with_multiple_countries JOIN time_consistent_cluster_geometry_pre_geocoding cluster USING(cluster_uid)
#     JOIN temp_country_geom_transformed country USING (gwcode, gwsyear, gweyear)
# ),
# cluster_country_intersection_areas_ranked AS (
#     SELECT cluster_uid, year, gwcode, RANK() OVER(PARTITION BY cluster_uid, year ORDER BY intersection_area DESC) AS area_rank
#     FROM cluster_country_intersection_areas
# )
# SELECT cluster_uid, year, gwcode
# FROM cluster_country_intersection_areas_ranked WHERE area_rank = 1;
#
# -- Temporary table of clusters that match with a single country (i.e., interior clusters)
# CREATE TEMPORARY TABLE temp_cluster_country_matching_single_countries ON COMMIT DROP AS
# WITH countries_matched_per_cluster AS (
#     SELECT cluster_uid, year, COUNT(*) AS n_matched_countries
#     FROM temp_cluster_country_matching
#     GROUP BY cluster_uid, year
# )
# SELECT cluster_uid, year, gwcode
# FROM temp_cluster_country_matching JOIN countries_matched_per_cluster USING (cluster_uid, year)
# WHERE n_matched_countries = 1;
#
# -- Final table of cluster-country matching where we cleaned clustered matching with multiple countries
# -- and added world bank codes
# CREATE TEMPORARY TABLE temp_cluster_country_matching_clean ON COMMIT DROP AS
# WITH cluster_country_matching AS (
#     SELECT * FROM temp_cluster_country_matching_single_countries
#     UNION ALL
#     SELECT * FROM temp_cluster_country_matching_multiple_countries)
# SELECT cluster_uid, year, gwcode AS cshape_code, world_bank_code
# FROM cluster_country_matching JOIN crosswalk_cshape_to_world_bank_codes
# ON gwcode = cshape_code;
#
# -- We add country information to the time consistent cluster table
# -- Note: by doing this we drop clusters that are matched to no country
# -- These are usually small clusters on islands off the coast of a country which are too small to be counted in the country border dataset.
# CREATE TABLE time_consistent_cluster AS
# SELECT cluster_uid, year, population, cshape_code, world_bank_code
# FROM time_consistent_cluster_pre_geocoding JOIN temp_cluster_country_matching_clean USING (cluster_uid, year);
#
# -- We filter the time consistent cluster geometry table to only include clusters that have country information
# CREATE TABLE time_consistent_cluster_geometry AS
# SELECT cluster_uid, geom
# FROM time_consistent_cluster_geometry_pre_geocoding
# WHERE cluster_uid IN (SELECT DISTINCT cluster_uid FROM time_consistent_cluster);
#
# ALTER TABLE "time_consistent_cluster_geometry" ADD PRIMARY KEY (cluster_uid);
# CREATE INDEX ON "time_consistent_cluster_geometry" USING GIST (geom);
#
# ALTER TABLE "time_consistent_cluster" ADD PRIMARY KEY (cluster_uid, year);
# ALTER TABLE "time_consistent_cluster" ADD FOREIGN KEY (cluster_uid) REFERENCES "time_consistent_cluster_geometry"(cluster_uid);
#
#
#
# 2024-07-23 23:20:32,484 INFO sqlalchemy.engine.Engine [generated in 0.00044s] {}
# 2024-07-23 23:20:45,163 INFO sqlalchemy.engine.Engine COMMIT
